# %%
# 查看当前挂载的数据集目录, 该目录下的变更重启环境后会自动还原
# View dataset directory. This directory will be recovered automatically after resetting environment. 
# !ls /home/aistudio/data

# %%
import moxing as mox
mox.file.copy('refMaskModel6.zip', 'obs://data-mask-3544/refMaskModel6.zip')

# %%
# 查看工作区文件, 该目录下的变更将会持久保存. 请及时清理不必要的文件, 避免加载过慢.
# View personal work directory. All changes under this directory will be kept even after reset. Please clean unnecessary files in time to speed up environment loading.
# !ls /home/aistudio/work

# %%
# 如果需要进行持久化安装, 需要使用持久化路径, 如下方代码示例:
# If a persistence installation is required, you need to use the persistence path as the following:
# !mkdir /home/aistudio/external-libraries
# !pip install beautifulsoup4 -t /home/aistudio/external-libraries

# %%
# 同时添加如下代码, 这样每次环境(kernel)启动的时候只要运行下方代码即可:
# Also add the following code, so that every time the environment (kernel) starts, just run the following code:
# import sys
# sys.path.append('/home/aistudio/external-libraries')

# %%
#get data from obs
import moxing as mox
#下载一个OBS文件夹sub_dir_0，从OBS下载至本地Notebook（OBS -> 本地）
mox.file.copy('obs://data-mask-3544/VOC_MASK.zip', '/home/ma-user/work/VOC_MASK.zip')
# Out:
# INFO:root:Using MoXing-v1.17.3-43fbf97f
# INFO:root:Using OBS-Python-SDK-3.20.7
# WARNING:root:Retry=9, Wait=0.1, Timestamp=1646486092.0831022
# WARNING:root:Retry=8, Wait=0.2, Timestamp=1646486092.3267436
# WARNING:root:Retry=7, Wait=0.4, Timestamp=1646486092.5426126
# WARNING:root:Retry=6, Wait=0.8, Timestamp=1646486092.9732113
# WARNING:root:Retry=5, Wait=1.6, Timestamp=1646486093.801838
# WARNING:root:Retry=4, Wait=3.2, Timestamp=1646486095.434335
# WARNING:root:Retry=3, Wait=6.4, Timestamp=1646486098.6568267
# WARNING:root:Retry=2, Wait=12.8, Timestamp=1646486105.0786579
# WARNING:root:Retry=1, Wait=25.6, Timestamp=1646486117.9076295
# ERROR:root:Failed to call:
# 	func=<bound method ObsClient.getObject of <moxing.framework.file.src.obs.client.ObsClient object at 0x7f8453055f90>>
# 	args=('data-mask-3544', 'VOC_MASK.zip')
# 	kwargs={loadStreamInMemory:False, }
# ERROR:root:
# 	stat:404
# 	errorCode:NoSuchKey
# 	errorMessage:The specified key does not exist.
# 	reason:Not Found
# 	request-id:0000017F5A385E0B90132843F346342D
# 	retry:0
# ---------------------------------------------------------------------------
# MoxFileNotExistsException                 Traceback (most recent call last)
# <ipython-input-5-b9c7e3f895c3> in <module>
#       2 import moxing as mox
#       3 #下载一个OBS文件夹sub_dir_0，从OBS下载至本地Notebook（OBS -> 本地）
# ----> 4 mox.file.copy('obs://data-mask-3544/VOC_MASK.zip', '/home/ma-user/work/VOC_MASK.zip')
#
# ~/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages/moxing/framework/util/runtime.py in wrapper(*args, **kwargs)
#     252
#     253     else:
# --> 254       return func(*args, **kwargs)
#     255
#     256   return functools.wraps(func)(wrapper)
#
# ~/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages/moxing/framework/file/file_io.py in wrapper(*args, **kwargs)
#     244         logging.warning('skip file not found: %s' % args[0])
#     245     else:
# --> 246       return func(*args, **kwargs)
#     247
#     248   return wrapper
#
# ~/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages/moxing/framework/file/file_io.py in copy(src_url, dst_url, client_id, atom)
#    1669     elif not src_local and dst_local:
#    1670       if not atom:
# -> 1671         _download_obs(obs_client, src_bucket_name, src_object_key, dst_object_key)
#    1672       else:
#    1673         _download_obs_atom(obs_client, src_bucket_name, src_object_key, dst_object_key)
#
# ~/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages/moxing/framework/file/file_io.py in _download_obs(obs_client, bucket_name, object_key, local_file)
#    1699   else:
#    1700     # _retryable_call(obs_client, 'getObject', bucket_name, object_key, downloadPath=local_file)
# -> 1701     _download_obs_by_stream(obs_client, bucket_name, object_key, local_file)
#    1702
#    1703
#
# ~/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages/moxing/framework/file/file_io.py in _download_obs_by_stream(obs_client, bucket_name, object_key, local_file)
#    1720
#    1721 def _download_obs_by_stream(obs_client, bucket_name, object_key, local_file):
# -> 1722   resp = _retryable_call(obs_client, 'getObject', bucket_name, object_key, loadStreamInMemory=False)
#    1723   response = resp.body.response
#    1724   read_func = response.read
#
# ~/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages/moxing/framework/file/file_io.py in _retryable_call(obs_client, func_name, *args, **kwargs)
#     692   else:
#     693     if resp.status == 404 and resp.errorCode in ('NoSuchKey', 'NoSuchBucket'):
# --> 694       raise MoxFileNotExistsException(resp, 'file or directory or bucket not found.')
#     695     else:
#     696       raise MoxFileRespException(
#
# MoxFileNotExistsException: [Errno {'status': 404, 'reason': 'Not Found', 'errorCode': 'NoSuchKey', 'errorMessage': 'The specified key does not exist.', 'body': None, 'requestId': '0000017F5A385E0B90132843F346342D', 'hostId': 'LXzIDegnPrSKScM6QngFWgMRJbeKyFRH7M3lGCw0Bo5LTy1NIdyQ4P6dk/fYMkpC', 'header': [('x-reserved', 'amazon, aws and amazon web services are trademarks or registered trademarks of Amazon Technologies, Inc'), ('request-id', '0000017F5A385E0B90132843F346342D'), ('id-2', '32AAAQAAEAABAAAQAAEAABAAAQAAEAABCSEtlap1asuvtCVuXj5a7LCH5y/0884n'), ('content-type', 'application/xml'), ('date', 'Sat, 05 Mar 2022 13:15:17 GMT'), ('content-length', '303')]}] file or directory or bucket not found.

# %%
# 解压 原本project 自带的数据 to ./masks
# !unzip VOC_MASK.zip
# Out:
# Archive:  VOC_MASK.zip
# replace VOC_MASK/Annotations/00000_Mask_Mouth_Chin.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# unzip the new data
# !unzip DATA/DATA1/JPEGImages.zip -d new_data/test/
# Out:
# unzip:  cannot find or open DATA/DATA1/JPEGImages.zip, DATA/DATA1/JPEGImages.zip.zip or DATA/DATA1/JPEGImages.zip.ZIP.

# %% [markdown]
# 1. 路径修改-> 本地路径
# 2. 数据集的问题
# 3.

# %%
import shutil
in_path = 'dataset_cui/dataset1/JPEGImages'
out_path='VOC_MASK/JPEGImages/'
for filepath,dirnames,filenames in os.walk(in_path):   #在多级目录下找图片 
        for filename in filenames:
            str1 = filename.split('.')[0]
            str1_1 = filename.split('.')[1]
            if str1_1 == "jpg" or str1_1 == "jpeg" or str1_1 == "JPG" or str1_1 == "JPEG":
                shutil.copy(filepath + "/" + filename, out_path) #! 复制文件,从in_path到out_path
                #shutil.move() 移动文件  
            else:
                continue
# Out:
# /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# 导入 xml 文件 从自己的 到 project 初始的

# %%
work_dir = "dataset_cui/dataset1/Annotations/"  # self_xml文件所在的目录
new_dir = 'VOC_MASK/Annotations/'  # dst_xml 文件所在的目录

for parent, dirnames, filenames in os.walk(work_dir,  followlinks=True):
    for filename in filenames:
        file_path = os.path.join(parent, filename)
        file = open(file_path, "r+", encoding='UTF-8')
        newFile = open(new_dir+filename, "w", encoding='UTF-8') # filename
        print(new_dir+filename)
        for line in file.readlines():    # 读取文件的每一行
             #! 修改标签为我们自己设定的然后再copy过去
            if("FIRC" in line):
                line = line.replace("FIRC", "Unknown")
            if("person" in line): # 直接把 person 改了
                line = line.replace("person", "not_standard")
            newFile.writelines(line)
        print(filename)
        newFile.close()
        file.close()

# %% [markdown]
# # 导入cv,paddlepaddle库

# %%
# !python -m pip install paddlepaddle-gpu==2.2.2.post101 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# !pip install opencv-python
# Out:
# Looking in indexes: http://repo.myhuaweicloud.com/repository/pypi/simple/
# Looking in links: https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# Collecting paddlepaddle-gpu==2.2.2.post101
#   Downloading https://paddle-wheel.bj.bcebos.com/2.2.2/linux/linux-gpu-cuda10.1-cudnn7-mkl-gcc5.4-avx/paddlepaddle_gpu-2.2.2.post101-cp37-cp37m-linux_x86_64.whl (434.3 MB)
#      |████████████████████████████████| 434.3 MB 1.8 kB/s  eta 0:00:012           | 6.0 MB 3.6 MB/s eta 0:02:00[K     |▉                               | 11.2 MB 3.6 MB/s eta 0:01:59                      | 19.8 MB 3.6 MB/s eta 0:01:571:55                      | 28.0 MB 3.6 MB/s eta 0:01:5435.1 MB 3.6 MB/s eta 0:01:5239.0 MB 3.6 MB/s eta 0:01:51                    | 67.7 MB 3.3 MB/s eta 0:01:53MB/s eta 0:01:31██▎                         | 85.8 MB 3.9 MB/s eta 0:01:294027               | 135.6 MB 3.6 MB/s eta 0:01:23    | 144.0 MB 149.0 MB/s eta 0:00:02��██████                     | 149.1 MB 149.0 MB/s eta 0:00:02█▏                    | 152.1 MB 149.0 MB/s eta 0:00:02��█████████                   | 176.5 MB 3.5 MB/s eta 0:01:15         | 181.8 MB 4.2 MB/s eta 0:01:014.2 MB/s eta 0:01:00███▍                 | 195.8 MB 4.2 MB/s eta 0:00:58████                 | 204.6 MB 4.2 MB/s eta 0:00:56��███████▏              | 233.3 MB 3.3 MB/s eta 0:01:01��███████▌              | 238.1 MB 3.8 MB/s eta 0:00:52   |██████████████████▏             | 247.1 MB 3.8 MB/s eta 0:00:49[K     |██████████████████▊             | 254.5 MB 3.8 MB/s eta 0:00:47   | 260.0 MB 3.8 MB/s eta 0:00:46��████████████████████▊          | 294.0 MB 3.5 MB/s eta 0:00:40��█████████████████████          | 299.2 MB 3.5 MB/s eta 0:00:39MB 3.5 MB/s eta 0:00:37MB 4.1 MB/s eta 0:00:30█████▌        | 319.1 MB 4.1 MB/s eta 0:00:29��████████████████▏       | 328.1 MB 4.1 MB/s eta 0:00:26��████████████████▉       | 336.5 MB 4.0 MB/s eta 0:00:25 | 366.4 MB 4.8 MB/s eta 0:00:15��██████▎    | 369.8 MB 104 kB/s eta 0:10:16��███▎    | 370.3 MB 52 kB/s eta 0:20:29     |███████████████████████████▋    | 375.4 MB 52 kB/s eta 0:18:51�███    | 381.4 MB 52 kB/s eta 0:16:56ta 0:23:119.6 MB 35 kB/s eta 0:21:07��███████████████   | 395.0 MB 35 kB/s eta 0:18:34�██ | 419.4 MB 86.4 MB/s eta 0:00:01
# Requirement already satisfied: Pillow in /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages (from paddlepaddle-gpu==2.2.2.post101) (9.0.1)
# Requirement already satisfied: six in /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages (from paddlepaddle-gpu==2.2.2.post101) (1.16.0)
# Requirement already satisfied: protobuf>=3.1.0 in /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages (from paddlepaddle-gpu==2.2.2.post101) (3.19.4)
# Requirement already satisfied: decorator in /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages (from paddlepaddle-gpu==2.2.2.post101) (5.1.1)
# Requirement already satisfied: numpy>=1.13 in /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages (from paddlepaddle-gpu==2.2.2.post101) (1.21.5)
# Requirement already satisfied: requests>=2.20.0 in /home/ma-user/modelarts/modelarts-sdk (from paddlepaddle-gpu==2.2.2.post101) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ma-user/modelarts/modelarts-sdk (from requests>=2.20.0->paddlepaddle-gpu==2.2.2.post101) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages (from requests>=2.20.0->paddlepaddle-gpu==2.2.2.post101) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ma-user/modelarts/modelarts-sdk (from requests>=2.20.0->paddlepaddle-gpu==2.2.2.post101) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ma-user/modelarts/modelarts-sdk (from requests>=2.20.0->paddlepaddle-gpu==2.2.2.post101) (3.3)
# Collecting astor
#   Downloading http://repo.myhuaweicloud.com/repository/pypi/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: astor, paddlepaddle-gpu
# Successfully installed astor-0.8.1 paddlepaddle-gpu-2.2.2.post101
# WARNING: You are using pip version 20.3.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/ma-user/anaconda3/envs/python-3.7.10/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: http://repo.myhuaweicloud.com/repository/pypi/simple/
# Collecting opencv-python
#   Downloading http://repo.myhuaweicloud.com/repository/pypi/packages/67/50/665a503167396ad347957bea0bd8d5c08c865030b2d1565ff06eba613780/opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      |████████████████████████████████| 60.5 MB 63.7 MB/s eta 0:00:01s eta 0:00:011    |██████████▊                     | 20.2 MB 63.7 MB/s eta 0:00:01�██████████▏                 | 26.9 MB 63.7 MB/s eta 0:00:01�███████████▏             | 34.3 MB 63.7 MB/s eta 0:00:01��████████████████████▉          | 41.3 MB 63.7 MB/s eta 0:00:01    |█████████████████████████████▏  | 55.3 MB 63.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5 in /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64
# WARNING: You are using pip version 20.3.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/ma-user/anaconda3/envs/python-3.7.10/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# #### 直接从这开始(如果数据处理好的话)

# %%
import xml.etree.cElementTree as ET
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import math
import paddle
import paddle.fluid as fluid
import myyolo3net as mynet
import time
import random
# Out:
# /modelarts/authoring/notebook-conda/lib/python3.7/site-packages/socks.py:58: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Callable

# %%
# 基本参数
xmlDir = r"VOC_MASK/Annotations"
imgDir = r"VOC_MASK/JPEGImages"
xmlList = [os.path.join(xmlDir, f) for f in os.listdir(xmlDir)]
labelDic = {'face': 0, 'face_mask': 1,'not_standard':2}
BATCH_SIZE = 16 
imgSize = (448,448)  # w,h
iouLim = 0.1
# anchorBox = [(40, 160), (80, 210), (80, 400)]  # 前宽后高
anchorBox = [(40, 40), (120, 120), (220, 220)]  # 前宽后高
colNum = imgSize[1] // 32
rowNum = imgSize[0] // 32
anchorNum = len(anchorBox)
classNum = len(labelDic)
outDim = (5 + classNum) * anchorNum
learningRate = 1e-4
testSize=96
random.shuffle(xmlList)
xmlListTest=xmlList[-testSize:]
xmlList=xmlList[0:-testSize]

#!!! 没有轮数吗?

# 从xml读图片，标签
def loadXmlandImg(xmlDir, loadImg=False, imgDir=imgDir, resize=False):
    # 输出的size是一个元组（w，h），theObjs为列表，每一位是一个字典，键name->标签，键box->[xxyy]
    xml = ET.parse(xmlDir)
    size = (
        int(xml.find("size").find("width").text),
        int(xml.find("size").find("height").text)
    )

    objs = xml.findall("object")
    theObjs = []
    # 遍历每个物品框生成一堆字典
    for obj in objs:
        bndbox = obj.find("bndbox")
        boxXXYY = [int(bndbox.find("xmin").text), int(bndbox.find("xmax").text),
                   int(bndbox.find("ymin").text), int(bndbox.find("ymax").text)]
        if resize:
            boxXXYY[0] *= resize[0] / size[0]
            boxXXYY[1] *= resize[0] / size[0]
            boxXXYY[2] *= resize[1] / size[1]
            boxXXYY[3] *= resize[1] / size[1]
        theObjs.append({
            "label": labelDic[obj.find("name").text],
            "box": boxXXYY
        })
    # 选择是不是加载图片
    if loadImg:
        fileName = xml.find("filename").text
        fileName = os.path.join(imgDir, fileName)
        img = cv2.imread(fileName)
        if resize:
            img = cv2.resize(img, resize)
        img = (cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype("float32") / 255.0).transpose(2, 0, 1)
        return size, theObjs, img
    else:
        return size, theObjs




# 构造yolo3真实框，输入真实框和框数上限，输出一个（框数，4）的xywh数组
def yolo3GTBoxLabel(gtBoxes, resize,boxNum=50):
    # gtBoxes，一个字典，包含label:01234和box:[x,x,y,y]两个键值对
    # shape = d['shapes']

    thisLabel = [0 for i in range(boxNum)]
    gtBoxArr = [[0, 0, 0, 0] for i in range(boxNum)]

    # 遍历这个图的每一个真实框
    for i in range(min(len(gtBoxes),boxNum)):
        box = gtBoxes[i]
        points = box['box']
        x1 = points[0]
        x2 = points[1]
        y1 = points[2]
        y2 = points[3]
        label = box['label']
        gtx = (x1 + x2) / 2
        gty = (y1 + y2) / 2
        gtw = x2 - x1
        gth = y2 - y1
        gtBoxArr[i] = [gtx/resize[0], gty/resize[1], gtw/resize[0], gth/resize[1]]
        thisLabel[i] = label
    # print(gtBoxArr,thisLabel)
    return np.array(gtBoxArr, dtype="float32"), np.array(thisLabel, dtype="int32")


# s, o, i = loadXmlandImg(os.path.join(xmlDir, xmlList[0]), True, imgDir)
# print(i.shape)


# 定义画矩形框的程序
def draw_rectangle(bbox, currentAxis=None, edgecolor='k', facecolor='y', fill=False, linestyle='-'):
    # currentAxis，坐标轴，通过plt.gca()获取
    # bbox，边界框，包含四个数值的list， [x1, x2, y1, y2]
    # edgecolor，边框线条颜色
    # facecolor，填充颜色
    # fill, 是否填充
    # linestype，边框线型
    # patches.Rectangle需要传入左上角坐标、矩形区域的宽度、高度等参数
    if not currentAxis:
        currentAxis = plt.gca()
    rect = patches.Rectangle((bbox[0], bbox[2]), bbox[1] - bbox[0] + 1, bbox[3] - bbox[2] + 1, linewidth=1,
                             edgecolor=edgecolor, facecolor=facecolor, fill=fill, linestyle=linestyle)
    currentAxis.add_patch(rect)

# 就是从一个 文件名到各种信息的转变 -> reader 
def dataReader2(xmllist, img_size=imgSize):#? 需要给imgsize吗？？？？
    labels = []
    gtboxes = []
    imgs = []
    for i in xmllist:   #             路径。 1. 
        # 得到图片的size, obj(详细信息width,height) , img本身
        size, obj, img = loadXmlandImg(i, True, resize=img_size)
        imgs.append(img)
        # print(obj)
        box, label = yolo3GTBoxLabel(obj, resize=imgSize)
        labels.append(label)
        gtboxes.append(box)
    return np.array(gtboxes, dtype="float32"), np.array(labels, dtype="int32"), np.array(imgs, dtype="float32")


# 构建网络

maxGTbox = 50
paddle.enable_static()
inputImg = fluid.layers.data("image", shape=[None, 3, imgSize[1], imgSize[0]], dtype="float32")
# inputLabel = fluid.layers.data("label", shape=[None, anchorNum, 5 + classNum, rowNum, colNum], dtype="float32")
inputLabel = fluid.layers.data("label", shape=[None, maxGTbox], dtype="int32")
inputGtbox = fluid.layers.data("gtbox", shape=[None, maxGTbox, 4], dtype="float32")
(C0, C1, C2) = mynet.Darknet53(inputImg)  # 经过骨干网络提取特征
(r0, t0, P0) = mynet.yoloMain(C0, outDim)  # 得到yolo3的0级输出
r0_resize = fluid.layers.resize_nearest(input=r0, scale=2)
C1_New = fluid.layers.concat(input=[r0_resize, C1], axis=1)  # 和C1拼起来
(r1, t1, P1) = mynet.yoloMain(C1_New, outDim)  # yolo3的1级输出
r1_resize = fluid.layers.resize_nearest(input=r1, scale=2)
C1_New = fluid.layers.concat(input=[r1_resize, C2], axis=1)    # 和二级拼起来
(r2, t2, P2) = mynet.yoloMain(C1_New, outDim)
print(P0, P1, P2)

# lossAvg = mynet.yolo3LossNet(P0, inputLabel)
lossAll0 = fluid.layers.yolov3_loss( # 使用paddle框架自己的loss定义损失函数 !!!
    x=P0,
    gt_box=inputGtbox,
    gt_label=inputLabel,
    anchors=[7, 10, 12, 22, 24, 17,22, 45, 46, 33, 43, 88,85, 66, 115, 146, 275, 240],
    anchor_mask=[6,7,8],
    class_num=classNum,
    ignore_thresh=iouLim,
    downsample_ratio=32
)
lossAll1 = fluid.layers.yolov3_loss(
    x=P1,
    gt_box=inputGtbox,
    gt_label=inputLabel,
    anchors=[7, 10, 12, 22, 24, 17,22, 45, 46, 33, 43, 88,85, 66, 115, 146, 275, 240],
    anchor_mask=[3,4,5],
    class_num=classNum,
    ignore_thresh=iouLim,
    downsample_ratio=16
)
lossAll2 = fluid.layers.yolov3_loss(
    x=P2,
    gt_box=inputGtbox,
    gt_label=inputLabel,
    anchors=[7, 10, 12, 22, 24, 17,22, 45, 46, 33, 43, 88,85, 66, 115, 146, 275, 240],
    anchor_mask=[0, 1, 2],
    class_num=classNum,
    ignore_thresh=iouLim,
    downsample_ratio=8
)
lossAll = lossAll0 + lossAll1 + lossAll2
lossAvg = fluid.layers.mean(lossAll)
print(lossAvg)
testProgram = fluid.default_main_program().clone(for_test=True)
opt = fluid.optimizer.Momentum(
    learning_rate=fluid.layers.piecewise_decay(boundaries=[800,1500,4000], values=[1e-3,3e-4,1e-4,5e-5]),
    # learning_rate=1e-4,
    momentum=0.9,
    # regularization=fluid.regularizer.L2Decay(0.0005),
)
a=opt.minimize(lossAvg)
# 开始训练
# Out:
# var leaky_relu_131.tmp_0 : LOD_TENSOR.shape(-1, 24, 14, 14).dtype(float32).stop_gradient(False) var leaky_relu_138.tmp_0 : LOD_TENSOR.shape(-1, 24, 28, 28).dtype(float32).stop_gradient(False) var leaky_relu_145.tmp_0 : LOD_TENSOR.shape(-1, 24, 56, 56).dtype(float32).stop_gradient(False)
# var mean_1.tmp_0 : LOD_TENSOR.shape(1,).dtype(float32).stop_gradient(False)
# /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages/paddle/fluid/layers/math_op_patch.py:341: UserWarning: <ipython-input-5-f254c0d69df0>:175
# The behavior of expression A + B has been unified with elementwise_add(X, Y, axis=-1) from Paddle 2.0. If your code works well in the older versions but crashes in this version, try to use elementwise_add(X, Y, axis=0) instead of A + B. This transitional warning will be dropped in the future.
#   op_type, op_type, EXPRESSION_MAP[method_name]))

# %%
print("开始编译网络")
initPro = fluid.default_startup_program()
mainProg = fluid.default_main_program()

# place = fluid.CPUPlace() #use cpu???
place = fluid.CUDAPlace(0) #use gpu 
exe = fluid.Executor(place)
exe.run(program=initPro)

def testModel():
    miniBatch=4
    begin=0
    end=miniBatch
    lossAll=0.0
    while end<=testSize:
        b, l, ii = dataReader2(xmlListTest[begin:end])
        lo=exe.run(testProgram,
        feed={
                    'image': ii,
                    "label": l,
                    'gtbox': b
        },
        fetch_list=[lossAvg]
        )
        lossAll+=lo[0]
        # print(lo[0])
        begin+=miniBatch
        end+=miniBatch
    print("损失：",lossAll/(testSize//miniBatch))
# Out:
# 开始编译网络

# %% [markdown]
# 现在的问题:
#
# 如何不使用之前训练的模型而直接预测,这份代码是通过之前的训练过的模型基础上进行fine-tune而生成的,但是我们修改了之后就用不了之前的模型了，需要从0开始重新训练，那么如何修改代码是一个问题 !!
#
# 已经解决:将下面cell中的第二行
#
# #fluid.io.load_persistables(exe,'./model', mainProg) # 直接注释掉?

# %%
#os.environ['FLAGS_eager_delete_tensor_gb'] = "0.0"

# %%
# TODO ...
#fluid.io.load_persistables(exe,'./model', mainProg) # 直接注释掉?
print("开始训练")
dataNum = len(xmlList)
print(dataNum) 
# TODO 看看总长度是多少???
# 总次数 = 5 * dataNum/BATCH_SIZE * 1 = ? 
for i in range(15):# 训练5次?    0226:改为2次
    print("This is {} times in big FOR".format(i))
    testModel() # 之前定义的函数
    random.shuffle(xmlList) # 将序列中的元素随机打乱 -》 打乱xmlList
    tic = time.time() # 记录时间 
    begin = 0
    end = BATCH_SIZE
    while end <= dataNum: # 小于总数据num
        b, l, ii = dataReader2(xmlList[begin:end]) # 读取list内的内容
        # ['VOC_MASK/Annotations\\00535_Mask_Mouth_Chin.xml'] => np.array类型的容易得到的数据
        # print(b.shape, l.shape, i.shape)
        for j in range(1):
            la = exe.run(
                program=mainProg,
                feed={
                    'image': ii,
                    "label": l,
                    'gtbox': b
                },
                fetch_list=[lossAvg]
            )# exe.run() 返回什么??
        # print(la)
        if begin%128==0: # change here?
            print(i,begin,la, time.time() - tic) # 打印训练的各种信息，时间等等
            # 写一个详细的 tips !!! 
        begin += BATCH_SIZE # 280s 一次
        end += BATCH_SIZE
# 训练了2h+,还是不知道结果怎么样????
# 显示中间过程!! 
# 暂时保存模型
fluid.io.save_persistables(exe, './model', fluid.default_main_program())     
# 第二次 20-30s一个batch !!!
        
# b, l, i = dataReader2(xmlList[0:1])
# print(b.shape, l.shape, i.shape)
# Out:
# 开始训练
# 8357
# This is 0 times in big FOR
# 损失： [145.1584]
# 0 0 [array([157.99606], dtype=float32)] 2.188985824584961
# 0 128 [array([161.30981], dtype=float32)] 20.493324995040894
# 0 256 [array([142.18883], dtype=float32)] 38.795912742614746
# 0 384 [array([146.61853], dtype=float32)] 57.593847036361694
# 0 512 [array([147.26389], dtype=float32)] 76.47021675109863
# 0 640 [array([146.62448], dtype=float32)] 95.531170129776
# 0 768 [array([137.0969], dtype=float32)] 114.65670228004456
# 0 896 [array([153.5064], dtype=float32)] 134.0480535030365
# 0 1024 [array([130.37071], dtype=float32)] 152.8032624721527
# 0 1152 [array([139.43562], dtype=float32)] 171.62709999084473
# 0 1280 [array([128.29022], dtype=float32)] 190.3366003036499
# 0 1408 [array([123.8621], dtype=float32)] 209.22962617874146
# 0 1536 [array([125.26399], dtype=float32)] 227.8350429534912
# 0 1664 [array([130.24663], dtype=float32)] 247.04777002334595
# 0 1792 [array([126.76189], dtype=float32)] 265.89901208877563
# 0 1920 [array([121.833984], dtype=float32)] 284.86052894592285
# 0 2048 [array([137.38333], dtype=float32)] 303.56144523620605
# 0 2176 [array([126.65378], dtype=float32)] 322.361328125
# 0 2304 [array([148.58623], dtype=float32)] 341.266872882843
# 0 2432 [array([113.31038], dtype=float32)] 360.2154314517975
# 0 2560 [array([139.3472], dtype=float32)] 379.2220377922058
# 0 2688 [array([116.914856], dtype=float32)] 398.24632024765015
# 0 2816 [array([115.79619], dtype=float32)] 417.2066767215729
# 0 2944 [array([152.74646], dtype=float32)] 436.1082239151001
# 0 3072 [array([116.122154], dtype=float32)] 454.74679589271545
# 0 3200 [array([111.414], dtype=float32)] 473.66131925582886
# 0 3328 [array([118.31683], dtype=float32)] 492.4780580997467
# 0 3456 [array([115.20301], dtype=float32)] 511.39466619491577
# 0 3584 [array([120.03523], dtype=float32)] 530.4355094432831
# 0 3712 [array([117.44153], dtype=float32)] 549.4770896434784
# 0 3840 [array([111.71834], dtype=float32)] 568.6088547706604
# 0 3968 [array([112.91868], dtype=float32)] 587.6157591342926
# 0 4096 [array([108.81845], dtype=float32)] 606.6324112415314
# 0 4224 [array([120.450714], dtype=float32)] 625.5244851112366
# 0 4352 [array([111.16964], dtype=float32)] 644.5683898925781
# 0 4480 [array([110.761536], dtype=float32)] 663.5119893550873
# 0 4608 [array([111.284424], dtype=float32)] 682.5882275104523
# 0 4736 [array([109.74927], dtype=float32)] 701.5712213516235
# 0 4864 [array([119.78706], dtype=float32)] 720.7181174755096
# 0 4992 [array([112.59734], dtype=float32)] 739.6197817325592
# 5 5504 [array([95.0202], dtype=float32)] 824.6157307624817
# 5 5632 [array([82.66505], dtype=float32)] 843.8742923736572
# 5 5760 [array([81.561676], dtype=float32)] 863.0238535404205
# 5 5888 [array([102.35397], dtype=float32)] 882.2492523193359
# 5 6016 [array([74.35134], dtype=float32)] 901.2322645187378
# 5 6144 [array([76.60144], dtype=float32)] 920.5368249416351
# 5 6272 [array([78.90809], dtype=float32)] 939.808198928833
# 5 6400 [array([76.328476], dtype=float32)] 959.1960747241974
# 5 6528 [array([76.679306], dtype=float32)] 978.4862148761749
# 5 6656 [array([90.52644], dtype=float32)] 998.029935836792
# 5 6784 [array([76.905], dtype=float32)] 1017.4006490707397
# 5 6912 [array([86.35984], dtype=float32)] 1036.8165228366852
# 5 7040 [array([82.0186], dtype=float32)] 1056.0939576625824
# 5 7168 [array([97.143295], dtype=float32)] 1075.6756205558777
# 5 7296 [array([79.75333], dtype=float32)] 1095.0811455249786
# 5 7424 [array([134.42442], dtype=float32)] 1114.729647397995
# 5 7552 [array([81.362], dtype=float32)] 1133.974646806717
# 5 7680 [array([92.7077], dtype=float32)] 1153.1854646205902
# 5 7808 [array([76.3331], dtype=float32)] 1172.1430613994598
# 5 7936 [array([77.94466], dtype=float32)] 1191.1756300926208
# 5 8064 [array([89.538895], dtype=float32)] 1210.2511911392212
# 5 8192 [array([112.303345], dtype=float32)] 1229.5821018218994
# 5 8320 [array([81.10765], dtype=float32)] 1248.7333748340607
# This is 6 times in big FOR
# 损失： [79.99838]
# 6 0 [array([75.03088], dtype=float32)] 2.3402445316314697
# 6 128 [array([84.91404], dtype=float32)] 21.24065136909485
# 6 256 [array([76.68691], dtype=float32)] 40.3685200214386
# 6 384 [array([74.982376], dtype=float32)] 59.37340331077576
# 6 512 [array([82.89128], dtype=float32)] 78.56669235229492
# 6 640 [array([99.79917], dtype=float32)] 97.49421501159668
# 6 768 [array([81.57962], dtype=float32)] 116.6357741355896
# 6 896 [array([87.69777], dtype=float32)] 135.6343379020691
# 6 1024 [array([92.87422], dtype=float32)] 154.84378147125244
# 6 1152 [array([93.54851], dtype=float32)] 173.76952648162842
# 6 1280 [array([99.51256], dtype=float32)] 192.93445563316345
# 6 1408 [array([78.72599], dtype=float32)] 211.95353960990906
# 6 1536 [array([76.99071], dtype=float32)] 231.39337253570557
# 6 1664 [array([78.98049], dtype=float32)] 250.80755019187927
# 6 1792 [array([75.77638], dtype=float32)] 270.28896975517273
# 6 1920 [array([82.74057], dtype=float32)] 289.4522490501404
# 6 2048 [array([89.38316], dtype=float32)] 308.5001389980316
# 6 2176 [array([74.4746], dtype=float32)] 327.4190003871918
# 6 2304 [array([82.783325], dtype=float32)] 346.6471574306488
# 6 2432 [array([99.66755], dtype=float32)] 365.9919402599335
# 6 2560 [array([116.90829], dtype=float32)] 385.321177482605
# 6 2688 [array([77.50458], dtype=float32)] 404.4893937110901
# 6 2816 [array([77.712494], dtype=float32)] 423.8057472705841
# 6 2944 [array([92.83126], dtype=float32)] 442.9290363788605
# 6 3072 [array([78.75807], dtype=float32)] 462.30175161361694
# 6 3200 [array([85.625946], dtype=float32)] 481.3718423843384
# 6 3328 [array([76.58151], dtype=float32)] 500.2632622718811
# 6 3456 [array([76.04002], dtype=float32)] 519.1771643161774
# 6 3584 [array([90.173805], dtype=float32)] 538.1773951053619
# 6 3712 [array([78.997574], dtype=float32)] 556.955060005188
# 6 3840 [array([82.465805], dtype=float32)] 575.7301685810089
# 6 3968 [array([98.55312], dtype=float32)] 594.6761071681976
# 6 4096 [array([73.44524], dtype=float32)] 613.7763848304749
# 6 4224 [array([78.96323], dtype=float32)] 632.7646141052246
# 6 4352 [array([77.78167], dtype=float32)] 651.8758924007416
# 6 4480 [array([75.63448], dtype=float32)] 670.7584202289581
# 6 4608 [array([86.96848], dtype=float32)] 689.7768230438232
# 6 4736 [array([79.292145], dtype=float32)] 708.7490403652191
# 6 4864 [array([74.13693], dtype=float32)] 727.8476588726044
# 6 4992 [array([86.726166], dtype=float32)] 746.6334736347198
# 6 5120 [array([79.13395], dtype=float32)] 765.679520368576
# 6 5248 [array([73.17673], dtype=float32)] 784.5661244392395
# 6 5376 [array([76.63153], dtype=float32)] 803.530600309372
# 6 5504 [array([78.70561], dtype=float32)] 822.5665526390076
# 6 5632 [array([80.968056], dtype=float32)] 841.982079744339
# 6 5760 [array([87.564125], dtype=float32)] 860.9620087146759
# 6 5888 [array([80.27515], dtype=float32)] 880.2159857749939
# 6 6016 [array([82.12277], dtype=float32)] 899.3588507175446
# 6 6144 [array([77.562515], dtype=float32)] 918.4144814014435
# 6 6272 [array([74.31639], dtype=float32)] 937.6549835205078
# 6 6400 [array([72.92127], dtype=float32)] 956.7095079421997
# 6 6528 [array([91.282166], dtype=float32)] 975.8692243099213
# 6 6656 [array([82.32153], dtype=float32)] 994.9002797603607
# 6 6784 [array([80.56555], dtype=float32)] 1014.1673381328583
# 6 6912 [array([77.184326], dtype=float32)] 1033.2806932926178
# 6 7040 [array([74.98062], dtype=float32)] 1052.5158739089966
# 6 7168 [array([89.05857], dtype=float32)] 1071.6046705245972
# 6 7296 [array([74.573074], dtype=float32)] 1090.8828930854797
# 6 7424 [array([74.49986], dtype=float32)] 1110.0838558673859
# 6 7552 [array([107.48475], dtype=float32)] 1129.3755118846893
# 6 7680 [array([74.0475], dtype=float32)] 1148.68732213974
# 6 7808 [array([106.74185], dtype=float32)] 1168.119590997696
# 6 7936 [array([78.522], dtype=float32)] 1187.4278483390808
# 6 8064 [array([105.7098], dtype=float32)] 1206.7872667312622
# 6 8192 [array([77.066574], dtype=float32)] 1225.8947637081146
# 6 8320 [array([88.41414], dtype=float32)] 1245.2273256778717
# This is 7 times in big FOR
# 损失： [419.363]
# 7 0 [array([75.146835], dtype=float32)] 2.4885613918304443
# 7 128 [array([77.18991], dtype=float32)] 21.46253228187561
# 7 256 [array([74.752304], dtype=float32)] 40.63064408302307
# 7 384 [array([72.63147], dtype=float32)] 59.6407790184021
# 7 512 [array([103.89676], dtype=float32)] 78.87052369117737
# 7 640 [array([76.31177], dtype=float32)] 97.69863104820251
# 7 768 [array([82.09241], dtype=float32)] 116.70481371879578
# 7 896 [array([79.504944], dtype=float32)] 135.72500586509705
# 7 1024 [array([73.50948], dtype=float32)] 154.7294144630432
# 7 1152 [array([75.836395], dtype=float32)] 173.9041862487793
# 7 1280 [array([117.316414], dtype=float32)] 192.8712863922119
# 7 1408 [array([73.15968], dtype=float32)] 212.00459933280945
# 7 1536 [array([83.53734], dtype=float32)] 230.94791293144226
# 7 1664 [array([73.53453], dtype=float32)] 250.04089212417603
# 7 1792 [array([73.85823], dtype=float32)] 269.03179240226746
# 7 1920 [array([72.92349], dtype=float32)] 288.3572611808777
# 7 2048 [array([71.27759], dtype=float32)] 307.53873443603516
# 7 2176 [array([79.29556], dtype=float32)] 326.7114746570587
# 7 2304 [array([73.91518], dtype=float32)] 345.52216696739197
# 7 2432 [array([73.85356], dtype=float32)] 364.57208609580994
# 7 2560 [array([75.57303], dtype=float32)] 383.46119809150696
# 7 2688 [array([78.94879], dtype=float32)] 402.3580286502838
# 7 2816 [array([77.43968], dtype=float32)] 421.31044006347656
# 7 2944 [array([72.11197], dtype=float32)] 440.46336340904236
# 7 3072 [array([78.284874], dtype=float32)] 459.3058090209961
# 7 3200 [array([81.56216], dtype=float32)] 478.5251109600067
# 7 3328 [array([75.35606], dtype=float32)] 497.5920264720917
# 7 3456 [array([81.42092], dtype=float32)] 516.8430664539337
# 7 3584 [array([73.44113], dtype=float32)] 535.9810163974762
# 7 3712 [array([72.705185], dtype=float32)] 555.2633624076843
# 7 3840 [array([73.215], dtype=float32)] 574.0996475219727
# 7 3968 [array([93.00209], dtype=float32)] 592.9739170074463
# 7 4096 [array([81.145874], dtype=float32)] 611.6228685379028
# 7 4224 [array([88.61156], dtype=float32)] 630.53417801857
# 7 4352 [array([88.21659], dtype=float32)] 649.2848844528198
# 7 4480 [array([75.07315], dtype=float32)] 668.3159365653992
# 7 4608 [array([71.2099], dtype=float32)] 687.268180847168
# 7 4736 [array([83.01393], dtype=float32)] 706.4388101100922
# 7 4864 [array([72.98077], dtype=float32)] 725.2947299480438
# 7 4992 [array([78.68428], dtype=float32)] 744.4079768657684
# 7 5120 [array([73.71605], dtype=float32)] 763.3299157619476
# 7 5248 [array([77.652855], dtype=float32)] 782.3626868724823
# 7 5376 [array([74.65108], dtype=float32)] 801.1393992900848
# 7 5504 [array([77.274475], dtype=float32)] 820.0954713821411
# 7 5632 [array([85.83219], dtype=float32)] 838.706292629242
# 7 5760 [array([116.41449], dtype=float32)] 857.5206425189972
# 7 5888 [array([83.16016], dtype=float32)] 876.2952828407288
# 7 6016 [array([71.09004], dtype=float32)] 895.2708265781403
# 7 6144 [array([87.940216], dtype=float32)] 914.0370717048645
# 7 6272 [array([75.94981], dtype=float32)] 933.0460481643677
# 7 6400 [array([104.91466], dtype=float32)] 951.853218793869
# 7 6528 [array([77.03906], dtype=float32)] 970.8452031612396
# 7 6656 [array([71.78386], dtype=float32)] 989.7395241260529
# 7 6784 [array([72.74558], dtype=float32)] 1008.7779877185822
# 7 6912 [array([80.4173], dtype=float32)] 1027.7908289432526
# 7 7040 [array([78.25673], dtype=float32)] 1046.9684677124023
# 7 7168 [array([78.01789], dtype=float32)] 1065.8957846164703
# 7 7296 [array([84.03796], dtype=float32)] 1084.968828201294
# 7 7424 [array([72.87067], dtype=float32)] 1103.8803431987762
# 7 7552 [array([82.265625], dtype=float32)] 1123.0516901016235
# 7 7680 [array([85.1655], dtype=float32)] 1141.880981206894
# 7 7808 [array([74.520515], dtype=float32)] 1160.912365436554
# 7 7936 [array([75.67334], dtype=float32)] 1179.8365647792816
# 7 8064 [array([76.20923], dtype=float32)] 1198.7705509662628
# 7 8192 [array([79.67317], dtype=float32)] 1217.948618888855
# 7 8320 [array([104.09005], dtype=float32)] 1236.951036453247
# This is 8 times in big FOR
# 损失： [184.28151]
# 8 0 [array([82.450294], dtype=float32)] 2.3329086303710938
# 8 128 [array([82.154724], dtype=float32)] 21.391576051712036
# 8 256 [array([73.320175], dtype=float32)] 40.284335136413574
# 8 384 [array([91.54261], dtype=float32)] 59.30384564399719
# 8 512 [array([73.51068], dtype=float32)] 78.19840836524963
# 8 640 [array([80.77443], dtype=float32)] 97.34657907485962
# 8 768 [array([69.16023], dtype=float32)] 116.16430974006653
# 8 896 [array([78.72205], dtype=float32)] 135.20422053337097
# 8 1024 [array([71.82065], dtype=float32)] 154.17507362365723
# 8 1152 [array([88.2752], dtype=float32)] 173.36275339126587
# 8 1280 [array([72.33443], dtype=float32)] 192.44111943244934
# 8 1408 [array([70.90619], dtype=float32)] 211.64421939849854
# 8 1536 [array([76.88902], dtype=float32)] 230.59030508995056
# 8 1664 [array([88.87285], dtype=float32)] 249.83400869369507
# 8 1792 [array([76.0813], dtype=float32)] 268.90524196624756
# 8 1920 [array([80.16975], dtype=float32)] 288.00721168518066
# 8 2048 [array([79.70362], dtype=float32)] 306.75172424316406
# 8 2176 [array([79.69101], dtype=float32)] 325.60800075531006
# 8 2304 [array([71.019844], dtype=float32)] 344.1453597545624
# 8 2432 [array([72.34646], dtype=float32)] 362.7570536136627
# 8 2560 [array([86.89801], dtype=float32)] 381.5604178905487
# 8 2688 [array([74.626144], dtype=float32)] 400.11117482185364
# 8 2816 [array([77.62979], dtype=float32)] 418.8826148509979
# 8 2944 [array([70.86281], dtype=float32)] 437.5491600036621
# 8 3072 [array([74.66617], dtype=float32)] 456.3885455131531
# 8 3200 [array([75.76486], dtype=float32)] 475.13962507247925
# 8 3328 [array([72.423515], dtype=float32)] 494.0678584575653
# 8 3456 [array([75.218994], dtype=float32)] 512.8631994724274
# 8 3584 [array([75.140015], dtype=float32)] 531.6291561126709
# 8 3712 [array([85.68947], dtype=float32)] 550.4791035652161
# 8 3840 [array([85.49832], dtype=float32)] 569.534006357193
# 8 3968 [array([70.16031], dtype=float32)] 588.5773887634277
# 8 4096 [array([84.83501], dtype=float32)] 607.509120464325
# 8 4224 [array([77.11314], dtype=float32)] 626.2503709793091
# 8 4352 [array([75.68036], dtype=float32)] 645.2764880657196
# 9 8320 [array([69.99619], dtype=float32)] 1242.388052225113
# This is 10 times in big FOR
# 损失： [109.57019]
# 10 0 [array([79.06981], dtype=float32)] 2.354717254638672
# 10 128 [array([72.77009], dtype=float32)] 21.426288843154907
# 10 256 [array([70.92562], dtype=float32)] 40.444968461990356
# 10 384 [array([76.46135], dtype=float32)] 59.747679471969604
# 10 512 [array([118.8794], dtype=float32)] 79.05055212974548
# 10 640 [array([102.95932], dtype=float32)] 98.34897923469543
# 10 768 [array([79.00131], dtype=float32)] 117.34455704689026
# 10 896 [array([72.21063], dtype=float32)] 136.48672366142273
# 10 1024 [array([73.87308], dtype=float32)] 155.48820686340332
# 10 1152 [array([82.81952], dtype=float32)] 174.81245851516724
# 10 1280 [array([71.708435], dtype=float32)] 193.9891324043274
# 10 1408 [array([107.5946], dtype=float32)] 213.35608220100403
# 10 1536 [array([67.56608], dtype=float32)] 232.45389342308044
# 10 1664 [array([87.019424], dtype=float32)] 251.75072836875916
# 10 1792 [array([69.23439], dtype=float32)] 270.99294567108154
# 10 1920 [array([74.98423], dtype=float32)] 290.5560507774353
# 10 2048 [array([87.626465], dtype=float32)] 309.56286120414734
# 10 2176 [array([93.89068], dtype=float32)] 328.9493901729584
# 10 2304 [array([70.925186], dtype=float32)] 348.21245408058167
# 10 2432 [array([83.49195], dtype=float32)] 367.6307032108307
# 10 2560 [array([70.72483], dtype=float32)] 386.8195457458496
# 10 2688 [array([71.419044], dtype=float32)] 406.1100265979767
# 10 2816 [array([77.8359], dtype=float32)] 424.87581276893616
# 10 2944 [array([81.96269], dtype=float32)] 443.7127983570099
# 10 3072 [array([67.41194], dtype=float32)] 462.3272907733917
# 10 3200 [array([74.50794], dtype=float32)] 481.13745951652527
# 10 3328 [array([71.15672], dtype=float32)] 499.9826428890228
# 10 3456 [array([70.56281], dtype=float32)] 519.202525138855
# 10 3584 [array([77.36627], dtype=float32)] 538.0058944225311
# 10 3712 [array([72.4644], dtype=float32)] 556.9585921764374
# 10 3840 [array([76.76712], dtype=float32)] 575.8448162078857
# 10 3968 [array([76.207214], dtype=float32)] 594.796799659729
# 10 4096 [array([70.77451], dtype=float32)] 613.7672522068024
# 10 4224 [array([72.35642], dtype=float32)] 632.8672752380371
# 10 4352 [array([65.74626], dtype=float32)] 651.6813516616821
# 10 4480 [array([70.645386], dtype=float32)] 670.6770827770233
# 10 4608 [array([95.74376], dtype=float32)] 689.4275388717651
# 10 4736 [array([76.659294], dtype=float32)] 708.3707478046417
# 10 4864 [array([69.53205], dtype=float32)] 727.3281481266022
# 10 4992 [array([91.01294], dtype=float32)] 746.5453145503998
# 10 5120 [array([68.02392], dtype=float32)] 765.3566596508026
# 10 5248 [array([75.27843], dtype=float32)] 784.5759468078613
# 10 5376 [array([76.972], dtype=float32)] 803.4229373931885
# 10 5504 [array([78.7014], dtype=float32)] 822.404375076294
# 10 5632 [array([89.21132], dtype=float32)] 841.6962673664093
# 10 5760 [array([76.89734], dtype=float32)] 860.7180092334747
# 10 5888 [array([65.97072], dtype=float32)] 879.8301527500153
# 10 6016 [array([71.04042], dtype=float32)] 898.7404680252075
# 10 6144 [array([68.17317], dtype=float32)] 917.7313187122345
# 10 6272 [array([75.11085], dtype=float32)] 936.672741651535
# 10 6400 [array([78.85267], dtype=float32)] 955.8491206169128
# 10 6528 [array([68.03586], dtype=float32)] 974.9362900257111
# 10 6656 [array([85.60402], dtype=float32)] 994.0513660907745
# 10 6784 [array([74.25046], dtype=float32)] 1013.0238959789276
# 10 6912 [array([76.64488], dtype=float32)] 1032.1540942192078
# 10 7040 [array([76.61403], dtype=float32)] 1051.1706817150116
# 10 7168 [array([78.65028], dtype=float32)] 1070.3611567020416
# 10 7296 [array([72.79333], dtype=float32)] 1089.3225457668304
# 10 7424 [array([94.96436], dtype=float32)] 1108.768619298935
# 10 7552 [array([69.42494], dtype=float32)] 1127.9888260364532
# 10 7680 [array([71.07794], dtype=float32)] 1147.3296155929565
# 10 7808 [array([72.58355], dtype=float32)] 1166.35098361969
# 10 7936 [array([77.884705], dtype=float32)] 1185.566359758377
# 10 8064 [array([69.247665], dtype=float32)] 1204.6694285869598
# 10 8192 [array([68.39429], dtype=float32)] 1223.972929239273
# 10 8320 [array([69.757034], dtype=float32)] 1242.960351228714
# This is 11 times in big FOR
# 损失： [188.55768]
# 11 0 [array([84.404686], dtype=float32)] 2.386958599090576
# 11 128 [array([69.08551], dtype=float32)] 21.547444343566895
# 11 256 [array([66.23861], dtype=float32)] 40.73212695121765
# 11 384 [array([71.181625], dtype=float32)] 59.89247393608093
# 11 512 [array([69.90039], dtype=float32)] 79.30867314338684
# 11 640 [array([70.37704], dtype=float32)] 98.57746243476868
# 11 768 [array([73.44001], dtype=float32)] 118.02925634384155
# 11 896 [array([73.48927], dtype=float32)] 137.3376383781433
# 11 1024 [array([69.86266], dtype=float32)] 156.60754442214966
# 11 1152 [array([69.61065], dtype=float32)] 175.6778838634491
# 11 1280 [array([74.761536], dtype=float32)] 195.05124163627625
# 11 1408 [array([87.82646], dtype=float32)] 214.3057370185852
# 11 1536 [array([68.13197], dtype=float32)] 233.66952657699585
# 11 1664 [array([75.47766], dtype=float32)] 252.85131549835205
# 11 1792 [array([71.279205], dtype=float32)] 271.8820812702179
# 11 1920 [array([71.92863], dtype=float32)] 290.5804994106293
# 11 2048 [array([75.772964], dtype=float32)] 309.4827115535736
# 11 2176 [array([70.136185], dtype=float32)] 328.29955077171326
# 11 2304 [array([66.62309], dtype=float32)] 347.2479212284088
# 11 2432 [array([71.68781], dtype=float32)] 365.9735941886902
# 11 2560 [array([87.12564], dtype=float32)] 384.9660885334015
# 11 2688 [array([72.86546], dtype=float32)] 403.7392554283142
# 11 2816 [array([84.02269], dtype=float32)] 422.77321434020996
# 11 2944 [array([71.795715], dtype=float32)] 441.7229082584381
# 11 3072 [array([80.32251], dtype=float32)] 460.8710300922394
# 11 3200 [array([72.596954], dtype=float32)] 479.79404401779175
# 11 3328 [array([69.029236], dtype=float32)] 498.7857713699341
# 11 3456 [array([72.83566], dtype=float32)] 517.6747043132782
# 14 2560 [array([65.79045], dtype=float32)] 386.4168655872345
# 14 2688 [array([82.69989], dtype=float32)] 405.5909113883972
# 14 2816 [array([66.75336], dtype=float32)] 424.98969197273254
# 14 2944 [array([83.3742], dtype=float32)] 444.14199471473694
# 14 3072 [array([66.796814], dtype=float32)] 463.4660141468048
# 14 3200 [array([69.53259], dtype=float32)] 482.77588391304016
# 14 3328 [array([62.903236], dtype=float32)] 502.30474281311035
# 14 3456 [array([69.96735], dtype=float32)] 521.5355756282806
# 14 3584 [array([65.72772], dtype=float32)] 540.9412806034088
# 14 3712 [array([65.13051], dtype=float32)] 560.1725628376007
# 14 3840 [array([83.266205], dtype=float32)] 579.577586889267
# 14 3968 [array([65.750175], dtype=float32)] 598.6679575443268
# 14 4096 [array([106.689415], dtype=float32)] 618.1013672351837
# 14 4224 [array([69.51305], dtype=float32)] 637.525799036026
# 14 4352 [array([68.27101], dtype=float32)] 657.1075038909912
# 14 4480 [array([61.95563], dtype=float32)] 676.2941598892212
# 14 4608 [array([72.80437], dtype=float32)] 695.5658853054047
# 14 4736 [array([65.727264], dtype=float32)] 714.8238346576691
# 14 4864 [array([65.48059], dtype=float32)] 734.0272016525269
# 14 4992 [array([74.030655], dtype=float32)] 753.1016693115234
# 14 5120 [array([64.765884], dtype=float32)] 772.3248481750488
# 14 5248 [array([66.085175], dtype=float32)] 791.485570192337
# 14 5376 [array([72.798874], dtype=float32)] 810.7668404579163
# 14 5504 [array([69.34923], dtype=float32)] 829.8975622653961
# 14 5632 [array([92.44039], dtype=float32)] 849.1610724925995
# 14 5760 [array([73.21135], dtype=float32)] 868.0966629981995
# 14 5888 [array([65.61087], dtype=float32)] 887.0065140724182
# 14 6016 [array([68.4796], dtype=float32)] 906.2564871311188
# 14 6144 [array([62.43045], dtype=float32)] 925.3816435337067
# 14 6272 [array([65.93549], dtype=float32)] 944.5788316726685
# 14 6400 [array([64.07132], dtype=float32)] 963.4692232608795
# 14 6528 [array([67.38763], dtype=float32)] 982.6471431255341
# 14 6656 [array([75.61151], dtype=float32)] 1001.7277843952179
# 14 6784 [array([67.05266], dtype=float32)] 1020.8851323127747
# 14 6912 [array([104.19394], dtype=float32)] 1040.0438673496246
# 14 7040 [array([63.411415], dtype=float32)] 1059.2541992664337
# 14 7168 [array([82.449036], dtype=float32)] 1078.2619578838348
# 14 7296 [array([68.39338], dtype=float32)] 1097.4634301662445
# 14 7424 [array([66.9967], dtype=float32)] 1116.5147671699524
# 14 7552 [array([61.23564], dtype=float32)] 1135.7957236766815
# 14 7680 [array([67.52935], dtype=float32)] 1154.9696469306946
# 14 7808 [array([71.392105], dtype=float32)] 1174.4845206737518
# 14 7936 [array([70.25625], dtype=float32)] 1193.7589848041534
# 14 8064 [array([64.5198], dtype=float32)] 1213.2755558490753
# 14 8192 [array([65.10887], dtype=float32)] 1232.5740931034088
# 14 8320 [array([69.71662], dtype=float32)] 1251.9686410427094

# %% [markdown]
# 训练到一半的时候就可以保存参数了!!!

# %%
# 保存模型
fluid.io.save_persistables(exe, './model', fluid.default_main_program())

# %%
# 保存预测模型
fluid.io.save_inference_model("./refMaskModel/",
                              feeded_var_names=['image'],
                              target_vars=[P0,P1,P2],
                              executor=exe)
# Out:
# ['leaky_relu_58.tmp_0', 'leaky_relu_65.tmp_0', 'leaky_relu_72.tmp_0']

# %%
# 打包下载
# !zip -r refMaskModel6.zip refMaskModel
# Out:
#   adding: refMaskModel/ (stored 0%)
#   adding: refMaskModel/__model__ (deflated 98%)
#   adding: refMaskModel/batch_norm_0.b_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_0.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_0.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_0.w_2 (deflated 5%)
#   adding: refMaskModel/batch_norm_1.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_1.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_1.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_1.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_10.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_10.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_10.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_10.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_11.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_11.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_11.w_1 (deflated 2%)
#   adding: refMaskModel/batch_norm_11.w_2 (deflated 5%)
#   adding: refMaskModel/batch_norm_12.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_12.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_12.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_12.w_2 (deflated 0%)
#   adding: refMaskModel/batch_norm_13.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_13.w_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_13.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_13.w_2 (deflated 5%)
#   adding: refMaskModel/batch_norm_14.b_0 (deflated 0%)
#   adding: refMaskModel/batch_norm_14.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_14.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_14.w_2 (stored 0%)
#   adding: refMaskModel/batch_norm_15.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_15.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_15.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_15.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_16.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_16.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_16.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_16.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_17.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_17.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_17.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_17.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_18.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_18.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_18.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_18.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_19.b_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_19.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_19.w_1 (deflated 2%)
#   adding: refMaskModel/batch_norm_19.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_2.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_2.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_2.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_2.w_2 (deflated 5%)
#   adding: refMaskModel/batch_norm_20.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_20.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_20.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_20.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_21.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_21.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_21.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_21.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_22.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_22.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_22.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_22.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_23.b_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_23.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_23.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_23.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_24.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_24.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_24.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_24.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_25.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_25.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_25.w_1 (deflated 2%)
#   adding: refMaskModel/batch_norm_25.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_26.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_26.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_26.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_26.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_27.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_27.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_27.w_1 (deflated 2%)
#   adding: refMaskModel/batch_norm_27.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_28.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_28.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_28.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_28.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_29.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_29.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_29.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_29.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_3.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_3.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_3.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_3.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_30.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_30.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_30.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_30.w_2 (deflated 10%)
#   adding: refMaskModel/batch_norm_31.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_31.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_31.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_31.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_32.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_32.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_32.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_32.w_2 (deflated 10%)
#   adding: refMaskModel/batch_norm_33.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_33.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_33.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_33.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_34.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_34.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_34.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_34.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_35.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_35.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_35.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_35.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_36.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_36.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_36.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_36.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_37.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_37.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_37.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_37.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_38.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_38.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_38.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_38.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_39.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_39.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_39.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_39.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_4.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_4.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_4.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_4.w_2 (stored 0%)
#   adding: refMaskModel/batch_norm_40.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_40.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_40.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_40.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_41.b_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_41.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_41.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_41.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_42.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_42.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_42.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_42.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_43.b_0 (deflated 8%)
#   adding: refMaskModel/batch_norm_43.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_43.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_43.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_44.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_44.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_44.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_44.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_45.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_45.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_45.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_45.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_46.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_46.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_46.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_46.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_47.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_47.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_47.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_47.w_2 (deflated 14%)
#   adding: refMaskModel/batch_norm_48.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_48.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_48.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_48.w_2 (deflated 10%)
#   adding: refMaskModel/batch_norm_49.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_49.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_49.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_49.w_2 (deflated 14%)
#   adding: refMaskModel/batch_norm_5.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_5.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_5.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_5.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_50.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_50.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_50.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_50.w_2 (deflated 13%)
#   adding: refMaskModel/batch_norm_51.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_51.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_51.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_51.w_2 (deflated 14%)
#   adding: refMaskModel/batch_norm_52.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_52.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_52.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_52.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_53.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_53.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_53.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_53.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_54.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_54.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_54.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_54.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_55.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_55.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_55.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_55.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_56.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_56.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_56.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_56.w_2 (deflated 10%)
#   adding: refMaskModel/batch_norm_57.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_57.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_57.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_57.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_58.b_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_58.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_58.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_58.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_59.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_59.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_59.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_59.w_2 (deflated 9%)
#   adding: refMaskModel/batch_norm_6.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_6.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_6.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_6.w_2 (deflated 0%)
#   adding: refMaskModel/batch_norm_60.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_60.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_60.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_60.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_61.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_61.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_61.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_61.w_2 (deflated 9%)
#   adding: refMaskModel/batch_norm_62.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_62.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_62.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_62.w_2 (deflated 10%)
#   adding: refMaskModel/batch_norm_63.b_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_63.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_63.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_63.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_64.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_64.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_64.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_64.w_2 (deflated 10%)
#   adding: refMaskModel/batch_norm_65.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_65.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_65.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_65.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_66.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_66.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_66.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_66.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_67.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_67.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_67.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_67.w_2 (deflated 9%)
#   adding: refMaskModel/batch_norm_68.b_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_68.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_68.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_68.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_69.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_69.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_69.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_69.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_7.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_7.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_7.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_7.w_2 (deflated 0%)
#   adding: refMaskModel/batch_norm_70.b_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_70.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_70.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_70.w_2 (deflated 5%)
#   adding: refMaskModel/batch_norm_71.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_71.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_71.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_71.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_72.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_72.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_72.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_72.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_8.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_8.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_8.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_8.w_2 (deflated 0%)
#   adding: refMaskModel/batch_norm_9.b_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_9.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_9.w_1 (deflated 2%)
#   adding: refMaskModel/batch_norm_9.w_2 (deflated 5%)
#   adding: refMaskModel/conv2d_0.w_0 (deflated 5%)
#   adding: refMaskModel/conv2d_1.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_10.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_11.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_12.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_13.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_14.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_15.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_16.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_17.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_18.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_19.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_2.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_20.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_21.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_22.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_23.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_24.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_25.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_26.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_27.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_28.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_29.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_3.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_30.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_31.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_32.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_33.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_34.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_35.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_36.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_37.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_38.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_39.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_4.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_40.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_41.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_42.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_43.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_44.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_45.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_46.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_47.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_48.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_49.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_5.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_50.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_51.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_52.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_53.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_54.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_55.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_56.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_57.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_58.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_59.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_6.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_60.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_61.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_62.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_63.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_64.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_65.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_66.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_67.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_68.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_69.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_7.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_70.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_71.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_72.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_8.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_9.w_0 (deflated 7%)

# %%
# 打包下载
# !zip -r model_0226_maskDetection.zip model

# %%
#解压文件
# !unzip refMaskModel6.zip
# Out:
# /home/ma-user/anaconda3/envs/python-3.7.10/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Archive:  refMaskModel6.zip
#    creating: refMaskModel/
#   inflating: refMaskModel/__model__
#   inflating: refMaskModel/batch_norm_0.b_0
#   inflating: refMaskModel/batch_norm_0.w_0
#   inflating: refMaskModel/batch_norm_0.w_1
#   inflating: refMaskModel/batch_norm_0.w_2
#  extracting: refMaskModel/batch_norm_1.b_0
#  extracting: refMaskModel/batch_norm_1.w_0
#  extracting: refMaskModel/batch_norm_1.w_1
#   inflating: refMaskModel/batch_norm_1.w_2
#  extracting: refMaskModel/batch_norm_10.b_0
#  extracting: refMaskModel/batch_norm_10.w_0
#  extracting: refMaskModel/batch_norm_10.w_1
#   inflating: refMaskModel/batch_norm_10.w_2
#   inflating: refMaskModel/batch_norm_11.b_0
#   inflating: refMaskModel/batch_norm_11.w_0
#   inflating: refMaskModel/batch_norm_11.w_1
#   inflating: refMaskModel/batch_norm_11.w_2
#  extracting: refMaskModel/batch_norm_12.b_0
#  extracting: refMaskModel/batch_norm_12.w_0
#  extracting: refMaskModel/batch_norm_12.w_1
#   inflating: refMaskModel/batch_norm_12.w_2
#   inflating: refMaskModel/batch_norm_13.b_0
#   inflating: refMaskModel/batch_norm_13.w_0
#   inflating: refMaskModel/batch_norm_13.w_1
#   inflating: refMaskModel/batch_norm_13.w_2
#   inflating: refMaskModel/batch_norm_14.b_0
#  extracting: refMaskModel/batch_norm_14.w_0
#  extracting: refMaskModel/batch_norm_14.w_1
#  extracting: refMaskModel/batch_norm_14.w_2
#   inflating: refMaskModel/batch_norm_15.b_0
#   inflating: refMaskModel/batch_norm_15.w_0
#   inflating: refMaskModel/batch_norm_15.w_1
#   inflating: refMaskModel/batch_norm_15.w_2
#  extracting: refMaskModel/batch_norm_16.b_0
#  extracting: refMaskModel/batch_norm_16.w_0
#  extracting: refMaskModel/batch_norm_16.w_1
#   inflating: refMaskModel/batch_norm_16.w_2
#   inflating: refMaskModel/batch_norm_17.b_0
#   inflating: refMaskModel/batch_norm_17.w_0
#   inflating: refMaskModel/batch_norm_17.w_1
#   inflating: refMaskModel/batch_norm_17.w_2
#  extracting: refMaskModel/batch_norm_18.b_0
#  extracting: refMaskModel/batch_norm_18.w_0
#  extracting: refMaskModel/batch_norm_18.w_1
#   inflating: refMaskModel/batch_norm_18.w_2
#   inflating: refMaskModel/batch_norm_19.b_0
#   inflating: refMaskModel/batch_norm_19.w_0
#   inflating: refMaskModel/batch_norm_19.w_1
#   inflating: refMaskModel/batch_norm_19.w_2
#   inflating: refMaskModel/batch_norm_2.b_0
#   inflating: refMaskModel/batch_norm_2.w_0
#   inflating: refMaskModel/batch_norm_2.w_1
#   inflating: refMaskModel/batch_norm_2.w_2
#  extracting: refMaskModel/batch_norm_20.b_0
#  extracting: refMaskModel/batch_norm_20.w_0
#  extracting: refMaskModel/batch_norm_20.w_1
#   inflating: refMaskModel/batch_norm_20.w_2
#   inflating: refMaskModel/batch_norm_21.b_0
#   inflating: refMaskModel/batch_norm_21.w_0
#   inflating: refMaskModel/batch_norm_21.w_1
#   inflating: refMaskModel/batch_norm_21.w_2
#  extracting: refMaskModel/batch_norm_22.b_0
#  extracting: refMaskModel/batch_norm_22.w_0
#  extracting: refMaskModel/batch_norm_22.w_1
#   inflating: refMaskModel/batch_norm_22.w_2
#   inflating: refMaskModel/batch_norm_23.b_0
#   inflating: refMaskModel/batch_norm_23.w_0
#   inflating: refMaskModel/batch_norm_23.w_1
#   inflating: refMaskModel/batch_norm_23.w_2
#  extracting: refMaskModel/batch_norm_24.b_0
#  extracting: refMaskModel/batch_norm_24.w_0
#  extracting: refMaskModel/batch_norm_24.w_1
#   inflating: refMaskModel/batch_norm_24.w_2
#   inflating: refMaskModel/batch_norm_25.b_0
#   inflating: refMaskModel/batch_norm_25.w_0
#   inflating: refMaskModel/batch_norm_25.w_1
#   inflating: refMaskModel/batch_norm_25.w_2
#   inflating: refMaskModel/batch_norm_26.b_0
#   inflating: refMaskModel/batch_norm_26.w_0
#   inflating: refMaskModel/batch_norm_26.w_1
#   inflating: refMaskModel/batch_norm_26.w_2
#   inflating: refMaskModel/batch_norm_27.b_0
#   inflating: refMaskModel/batch_norm_27.w_0
#   inflating: refMaskModel/batch_norm_27.w_1
#   inflating: refMaskModel/batch_norm_27.w_2
#   inflating: refMaskModel/batch_norm_28.b_0
#   inflating: refMaskModel/batch_norm_28.w_0
#   inflating: refMaskModel/batch_norm_28.w_1
#   inflating: refMaskModel/batch_norm_28.w_2
#   inflating: refMaskModel/batch_norm_29.b_0
#   inflating: refMaskModel/batch_norm_29.w_0
#   inflating: refMaskModel/batch_norm_29.w_1
#   inflating: refMaskModel/batch_norm_29.w_2
#  extracting: refMaskModel/batch_norm_3.b_0
#  extracting: refMaskModel/batch_norm_3.w_0
#  extracting: refMaskModel/batch_norm_3.w_1
#   inflating: refMaskModel/batch_norm_3.w_2
#   inflating: refMaskModel/batch_norm_30.b_0
#   inflating: refMaskModel/batch_norm_30.w_0
#   inflating: refMaskModel/batch_norm_30.w_1
#   inflating: refMaskModel/batch_norm_30.w_2
#   inflating: refMaskModel/batch_norm_31.b_0
#   inflating: refMaskModel/batch_norm_31.w_0
#   inflating: refMaskModel/batch_norm_31.w_1
#   inflating: refMaskModel/batch_norm_31.w_2
#   inflating: refMaskModel/batch_norm_32.b_0
#   inflating: refMaskModel/batch_norm_32.w_0
#   inflating: refMaskModel/batch_norm_32.w_1
#   inflating: refMaskModel/batch_norm_32.w_2
#   inflating: refMaskModel/batch_norm_33.b_0
#   inflating: refMaskModel/batch_norm_33.w_0
#   inflating: refMaskModel/batch_norm_33.w_1
#   inflating: refMaskModel/batch_norm_33.w_2
#   inflating: refMaskModel/batch_norm_34.b_0
#   inflating: refMaskModel/batch_norm_34.w_0
#   inflating: refMaskModel/batch_norm_34.w_1
#   inflating: refMaskModel/batch_norm_34.w_2
#   inflating: refMaskModel/batch_norm_35.b_0
#   inflating: refMaskModel/batch_norm_35.w_0
#   inflating: refMaskModel/batch_norm_35.w_1
#   inflating: refMaskModel/batch_norm_35.w_2
#   inflating: refMaskModel/batch_norm_36.b_0
#   inflating: refMaskModel/batch_norm_36.w_0
#   inflating: refMaskModel/batch_norm_36.w_1
#   inflating: refMaskModel/batch_norm_36.w_2
#   inflating: refMaskModel/batch_norm_37.b_0
#   inflating: refMaskModel/batch_norm_37.w_0
#   inflating: refMaskModel/batch_norm_37.w_1
#   inflating: refMaskModel/batch_norm_37.w_2
#   inflating: refMaskModel/batch_norm_38.b_0
#   inflating: refMaskModel/batch_norm_38.w_0
#   inflating: refMaskModel/batch_norm_38.w_1
#   inflating: refMaskModel/batch_norm_38.w_2
#   inflating: refMaskModel/batch_norm_39.b_0
#   inflating: refMaskModel/batch_norm_39.w_0
#   inflating: refMaskModel/batch_norm_39.w_1
#   inflating: refMaskModel/batch_norm_39.w_2
#  extracting: refMaskModel/batch_norm_4.b_0
#  extracting: refMaskModel/batch_norm_4.w_0
#  extracting: refMaskModel/batch_norm_4.w_1
#  extracting: refMaskModel/batch_norm_4.w_2
#   inflating: refMaskModel/batch_norm_40.b_0
#   inflating: refMaskModel/batch_norm_40.w_0
#   inflating: refMaskModel/batch_norm_40.w_1
#   inflating: refMaskModel/batch_norm_40.w_2
#   inflating: refMaskModel/batch_norm_41.b_0
#   inflating: refMaskModel/batch_norm_41.w_0
#   inflating: refMaskModel/batch_norm_41.w_1
#   inflating: refMaskModel/batch_norm_41.w_2
#   inflating: refMaskModel/batch_norm_42.b_0
#   inflating: refMaskModel/batch_norm_42.w_0
#   inflating: refMaskModel/batch_norm_42.w_1
#   inflating: refMaskModel/batch_norm_42.w_2
#   inflating: refMaskModel/batch_norm_43.b_0
#   inflating: refMaskModel/batch_norm_43.w_0
#   inflating: refMaskModel/batch_norm_43.w_1
#   inflating: refMaskModel/batch_norm_43.w_2
#   inflating: refMaskModel/batch_norm_44.b_0
#   inflating: refMaskModel/batch_norm_44.w_0
#   inflating: refMaskModel/batch_norm_44.w_1
#   inflating: refMaskModel/batch_norm_44.w_2
#   inflating: refMaskModel/batch_norm_45.b_0
#   inflating: refMaskModel/batch_norm_45.w_0
#   inflating: refMaskModel/batch_norm_45.w_1
#   inflating: refMaskModel/batch_norm_45.w_2
#   inflating: refMaskModel/batch_norm_46.b_0
#   inflating: refMaskModel/batch_norm_46.w_0
#   inflating: refMaskModel/batch_norm_46.w_1
#   inflating: refMaskModel/batch_norm_46.w_2
#   inflating: refMaskModel/batch_norm_47.b_0
#   inflating: refMaskModel/batch_norm_47.w_0
#   inflating: refMaskModel/batch_norm_47.w_1
#   inflating: refMaskModel/batch_norm_47.w_2
#   inflating: refMaskModel/batch_norm_48.b_0
#   inflating: refMaskModel/batch_norm_48.w_0
#   inflating: refMaskModel/batch_norm_48.w_1
#   inflating: refMaskModel/batch_norm_48.w_2
#   inflating: refMaskModel/batch_norm_49.b_0
#   inflating: refMaskModel/batch_norm_49.w_0
#   inflating: refMaskModel/batch_norm_49.w_1
#   inflating: refMaskModel/batch_norm_49.w_2
#  extracting: refMaskModel/batch_norm_5.b_0
#  extracting: refMaskModel/batch_norm_5.w_0
#  extracting: refMaskModel/batch_norm_5.w_1
#   inflating: refMaskModel/batch_norm_5.w_2
#   inflating: refMaskModel/batch_norm_50.b_0
#   inflating: refMaskModel/batch_norm_50.w_0
#   inflating: refMaskModel/batch_norm_50.w_1
#   inflating: refMaskModel/batch_norm_50.w_2
#   inflating: refMaskModel/batch_norm_51.b_0
#   inflating: refMaskModel/batch_norm_51.w_0
#   inflating: refMaskModel/batch_norm_51.w_1
#   inflating: refMaskModel/batch_norm_51.w_2
#   inflating: refMaskModel/batch_norm_52.b_0
#   inflating: refMaskModel/batch_norm_52.w_0
#   inflating: refMaskModel/batch_norm_52.w_1
#   inflating: refMaskModel/batch_norm_52.w_2
#   inflating: refMaskModel/batch_norm_53.b_0
#   inflating: refMaskModel/batch_norm_53.w_0
#   inflating: refMaskModel/batch_norm_53.w_1
#   inflating: refMaskModel/batch_norm_53.w_2
#   inflating: refMaskModel/batch_norm_54.b_0
#   inflating: refMaskModel/batch_norm_54.w_0
#   inflating: refMaskModel/batch_norm_54.w_1
#   inflating: refMaskModel/batch_norm_54.w_2
#   inflating: refMaskModel/batch_norm_55.b_0
#   inflating: refMaskModel/batch_norm_55.w_0
#   inflating: refMaskModel/batch_norm_55.w_1
#   inflating: refMaskModel/batch_norm_55.w_2
#   inflating: refMaskModel/batch_norm_56.b_0
#   inflating: refMaskModel/batch_norm_56.w_0
#   inflating: refMaskModel/batch_norm_56.w_1
#   inflating: refMaskModel/batch_norm_56.w_2
#   inflating: refMaskModel/batch_norm_57.b_0
#   inflating: refMaskModel/batch_norm_57.w_0
#   inflating: refMaskModel/batch_norm_57.w_1
#   inflating: refMaskModel/batch_norm_57.w_2
#   inflating: refMaskModel/batch_norm_58.b_0
#   inflating: refMaskModel/batch_norm_58.w_0
#   inflating: refMaskModel/batch_norm_58.w_1
#   inflating: refMaskModel/batch_norm_58.w_2
#   inflating: refMaskModel/batch_norm_59.b_0
#   inflating: refMaskModel/batch_norm_59.w_0
#   inflating: refMaskModel/batch_norm_59.w_1
#   inflating: refMaskModel/batch_norm_59.w_2
#  extracting: refMaskModel/batch_norm_6.b_0
#  extracting: refMaskModel/batch_norm_6.w_0
#  extracting: refMaskModel/batch_norm_6.w_1
#   inflating: refMaskModel/batch_norm_6.w_2
#   inflating: refMaskModel/batch_norm_60.b_0
#   inflating: refMaskModel/batch_norm_60.w_0
#   inflating: refMaskModel/batch_norm_60.w_1
#   inflating: refMaskModel/batch_norm_60.w_2
#   inflating: refMaskModel/batch_norm_61.b_0
#   inflating: refMaskModel/batch_norm_61.w_0
#   inflating: refMaskModel/batch_norm_61.w_1
#   inflating: refMaskModel/batch_norm_61.w_2
#   inflating: refMaskModel/batch_norm_62.b_0
#   inflating: refMaskModel/batch_norm_62.w_0
#   inflating: refMaskModel/batch_norm_62.w_1
#   inflating: refMaskModel/batch_norm_62.w_2
#   inflating: refMaskModel/batch_norm_63.b_0
#   inflating: refMaskModel/batch_norm_63.w_0
#   inflating: refMaskModel/batch_norm_63.w_1
#   inflating: refMaskModel/batch_norm_63.w_2
#   inflating: refMaskModel/batch_norm_64.b_0
#   inflating: refMaskModel/batch_norm_64.w_0
#   inflating: refMaskModel/batch_norm_64.w_1
#   inflating: refMaskModel/batch_norm_64.w_2
#   inflating: refMaskModel/batch_norm_65.b_0
#   inflating: refMaskModel/batch_norm_65.w_0
#   inflating: refMaskModel/batch_norm_65.w_1
#   inflating: refMaskModel/batch_norm_65.w_2
#   inflating: refMaskModel/batch_norm_66.b_0
#   inflating: refMaskModel/batch_norm_66.w_0
#   inflating: refMaskModel/batch_norm_66.w_1
#   inflating: refMaskModel/batch_norm_66.w_2
#   inflating: refMaskModel/batch_norm_67.b_0
#   inflating: refMaskModel/batch_norm_67.w_0
#   inflating: refMaskModel/batch_norm_67.w_1
#   inflating: refMaskModel/batch_norm_67.w_2
#   inflating: refMaskModel/batch_norm_68.b_0
#   inflating: refMaskModel/batch_norm_68.w_0
#   inflating: refMaskModel/batch_norm_68.w_1
#   inflating: refMaskModel/batch_norm_68.w_2
#   inflating: refMaskModel/batch_norm_69.b_0
#   inflating: refMaskModel/batch_norm_69.w_0
#   inflating: refMaskModel/batch_norm_69.w_1
#   inflating: refMaskModel/batch_norm_69.w_2
#  extracting: refMaskModel/batch_norm_7.b_0
#  extracting: refMaskModel/batch_norm_7.w_0
#  extracting: refMaskModel/batch_norm_7.w_1
#   inflating: refMaskModel/batch_norm_7.w_2
#   inflating: refMaskModel/batch_norm_70.b_0
#   inflating: refMaskModel/batch_norm_70.w_0
#   inflating: refMaskModel/batch_norm_70.w_1
#   inflating: refMaskModel/batch_norm_70.w_2
#   inflating: refMaskModel/batch_norm_71.b_0
#   inflating: refMaskModel/batch_norm_71.w_0
#   inflating: refMaskModel/batch_norm_71.w_1
#   inflating: refMaskModel/batch_norm_71.w_2
#   inflating: refMaskModel/batch_norm_72.b_0
#   inflating: refMaskModel/batch_norm_72.w_0
#   inflating: refMaskModel/batch_norm_72.w_1
#   inflating: refMaskModel/batch_norm_72.w_2
#  extracting: refMaskModel/batch_norm_8.b_0
#  extracting: refMaskModel/batch_norm_8.w_0
#  extracting: refMaskModel/batch_norm_8.w_1
#   inflating: refMaskModel/batch_norm_8.w_2
#   inflating: refMaskModel/batch_norm_9.b_0
#   inflating: refMaskModel/batch_norm_9.w_0
#   inflating: refMaskModel/conv2d_65.w_0
#   inflating: refMaskModel/conv2d_66.w_0
#   inflating: refMaskModel/conv2d_67.w_0
#   inflating: refMaskModel/conv2d_68.w_0
#   inflating: refMaskModel/conv2d_69.w_0
#   inflating: refMaskModel/conv2d_7.w_0
#   inflating: refMaskModel/conv2d_70.w_0
#   inflating: refMaskModel/conv2d_71.w_0
#   inflating: refMaskModel/conv2d_72.w_0
#   inflating: refMaskModel/conv2d_8.w_0
#   inflating: refMaskModel/conv2d_9.w_0

# %%
fluid.io.load_persistables(exe,'./model', mainProg) # 直接注释掉?

# %%
# 预测模型
import cv2
import numpy as np
import paddle.fluid as fluid
import time
import matplotlib.pyplot as plt
import math
import matplotlib.patches as patches

print("开始运行")

fluid.Scope()

## 加载所有文件的路径，每个文件在数组中有一位
modelPath = r'refMaskModel'
dataMap = {'face': 0, 'face_mask': 1,'not_rule':2}  #这里应该有三种预测，
classNum = 3          #这也应该为3
limObj = 0.8
iouLim=0.1

## 加载模型
place = fluid.CUDAPlace(0)
mainProg = fluid.default_main_program()
exe = fluid.Executor(place)


#fluid.io.load_inference_model载入我们训练的模型

[inference_program,  # 预测用的program
 feed_target_names,  # 一个str列表，它包含需要在预测 Program 中提供数据的变量的名称。
 fetch_targets] = fluid.io.load_inference_model(
    modelPath,
    exe
)


# 测试模型

def loadImg(path):
    img = cv2.imread(path)
    # print(img)
    img = cv2.resize(img, (448, 448), interpolation=cv2.INTER_AREA)
    img = (cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype("float32") / 255.0).transpose(2, 0, 1)
    return np.array([img], dtype="float32")


def sigma(x):
    return 1 / (1 + math.exp(-x))


def draw_rectangle(bbox, currentAxis=None, edgecolor='k', facecolor='y', fill=False, linestyle='-'):
    # currentAxis，坐标轴，通过plt.gca()获取
    # bbox，边界框，包含四个数值的list， [x1, x2, y1, y2]
    # edgecolor，边框线条颜色
    # facecolor，填充颜色
    # fill, 是否填充
    # linestype，边框线型
    # patches.Rectangle需要传入左上角坐标、矩形区域的宽度、高度等参数
    if not currentAxis:
        currentAxis = plt.gca()
    rect = patches.Rectangle((bbox[0], bbox[2]), bbox[1] - bbox[0] + 1, bbox[3] - bbox[2] + 1, linewidth=1,
                             edgecolor=edgecolor, facecolor=facecolor, fill=fill, linestyle=linestyle)
    currentAxis.add_patch(rect)


    #求交并比，计算两个矩形的交并比，通常在检测任务里面可以作为一个检测指标。你的预测bbox和groundtruth之间的差异，就可以通过IOU来体现。
def getIOU(xxyy1, xxyy2):
    x2 = min(xxyy1[1], xxyy2[1])
    x1 = max(xxyy1[0], xxyy2[0])
    y1 = max(xxyy1[2], xxyy2[2])
    y2 = min(xxyy1[3], xxyy2[3])

    if (x2 < x1) or (y1 > y2):
        return 0.0
    else:
        i = (x2 - x1) * (y2 - y1)
        s1 = (xxyy1[1] - xxyy1[0]) * (xxyy1[3] - xxyy1[2])
        s2 = (xxyy2[1] - xxyy2[0]) * (xxyy2[3] - xxyy2[2])
        return i / (s1 + s2 - i)


def refImg(imgPath):
    # maybeBox = [[] for i in range(classNum)]
    maybeBox = []
    img = loadImg(imgPath)

    def logBox(pred, stride, archors):
        pred0_ = pred[0]
        archorNum = len(archors) // 2
        for i in range(pred0_.shape[1]):
            for j in range(pred0_.shape[2]):
                for p in range(archorNum):
                    if sigma(pred0_[4 + p * (5 + classNum), i, j]) > limObj:
                        res = pred0_[p * (5 + classNum):(p + 1) * (5 + classNum), i, j]
                        x = stride * (j + sigma(res[0]))
                        y = stride * (i + sigma(res[1]))
                        w = archors[p * 2] * math.exp(res[2])
                        h = archors[p * 2 + 1] * math.exp(res[3])
                        max_ = (-1000)
                        maxClass = -1
                        # 比较是脸还是口罩
#                         if res[5] > res[6]:
#                             maxClass = 0
#                         else:
#                             maxClass = 1

                        for c in range(5, 5 + classNum):
                            if res[c] > max_:
                                max_ = res[c]
                                maxClass = c - 5

                        maybeBox.append({
                            "bbox": [x - w / 2, x + w / 2, y - h / 2, y + h / 2],
                            "obj": sigma(res[5 + maxClass]),
                            "state": 0,
                            "class": maxClass,
                            "stride": stride
                        })

    tic = time.time()
    pred0, pred1, pred2 = exe.run(
        program=inference_program,
        feed={feed_target_names[0]: img},
        fetch_list=fetch_targets
    )
    print(time.time() - tic)
    logBox(pred0, stride=32, archors=[85, 66, 115, 146, 275, 240])
    logBox(pred1, stride=16, archors=[22, 45, 46, 33, 43, 88])
    logBox(pred2, stride=8, archors=[7, 10, 12, 22, 24, 17])
    # print(maybeBox)
    plt.imshow(img[0].transpose(1, 2, 0))
    # goodBox0 = [[] for i in range(classNum)]
    # 去除多余的框
    # for i in range(classNum):
    while True:
        finish = True
        max_ = -1
        maxBox = 0
        for box in maybeBox:
            if box["state"] == 0 and box["obj"] > max_:
                finish = False
                max_ = box["obj"]
                maxBox = box
        if not finish:
            maxBox["state"] = 2
        for box in maybeBox:
            if box["state"] == 0 and getIOU(box["bbox"], maxBox["bbox"]) > 0.1:
                box["state"] = 1
        if finish:
            break

    # print("face")
    for box in maybeBox:
        if box["state"] == 2:
            print(box)
            if box["class"] == 0:
                draw_rectangle(box["bbox"], edgecolor='r')
            else:
                draw_rectangle(box["bbox"])

    # print("facemask")
    # for box in maybeBox[1]:
    #     if box["state"] == 2:
    #         print(box)
    #         draw_rectangle(box["bbox"])

    plt.show()

#  
# todo 修改展示函数!!!! evaluate
refImg(r"./VOC_MASK/JPEGImages/test_00000331.jpg") # 不规范
# 4_Dancing_Dancing_4_6
# refImg(r"./VOC_MASK/JPEGImages/1_Handshaking_Handshaking_1_341.jpg")
# refImg(r"./VOC_MASK/JPEGImages/00002_Mask_Mouth_Chin.jpg")
# Out:
# 开始运行
# 0.10544705390930176
# {'bbox': [139.5856759791709, 403.52603949384286, -0.37172681755495773, 306.1003616261902], 'obj': 0.9910561551953981, 'state': 2, 'class': 1, 'stride': 32}

# %%
# !ls
# Out:
# 3230486.ipynb	     home   myyolo3net.py  refMaskModel       VOC_MASK
# cui_mask_test.ipynb  model  __pycache__    refMaskModel6.zip  VOC_MASK.zip

# %%
# for i in range(1,15):
#     refImg("mymask/%d.jpg"%i)
