# %%
# 查看当前挂载的数据集目录, 该目录下的变更重启环境后会自动还原
# View dataset directory. This directory will be recovered automatically after resetting environment. 
# !ls /home/aistudio/data
# !/Users/hexiangyu/Downloads/easyFL-main/venv/bin/python -m pip install --upgrade pip
import cv2
# Out:
# ls: /home/aistudio/data: No such file or directory
# Requirement already satisfied: pip in /Users/hexiangyu/Downloads/easyFL-main/venv/lib/python3.6/site-packages (21.3.1)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-0924fce9ea15> in <module>
#       3 get_ipython().system('ls /home/aistudio/data')
#       4 get_ipython().system('/Users/hexiangyu/Downloads/easyFL-main/venv/bin/python -m pip install --upgrade pip')
# ----> 5 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# 查看工作区文件, 该目录下的变更将会持久保存. 请及时清理不必要的文件, 避免加载过慢.
# View personal work directory. All changes under this directory will be kept even after reset. Please clean unnecessary files in time to speed up environment loading.
# !ls /home/aistudio/work
# Out:
# ls: /home/aistudio/work: No such file or directory

# %%
# 如果需要进行持久化安装, 需要使用持久化路径, 如下方代码示例:
# If a persistence installation is required, you need to use the persistence path as the following:
# !mkdir /home/aistudio/external-libraries
# !pip install beautifulsoup4 -t /home/aistudio/external-libraries
# Out:
# mkdir: /home/aistudio: No such file or directory
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 178 kB/s eta 0:00:011
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.10.0 soupsieve-2.3.1
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/hexiangyu/Downloads/easyFL-main/venv/lib/python3.6/site-packages/pip/_internal/cli/base_command.py", line 173, in _main
#     status = self.run(options, args)
#   File "/Users/hexiangyu/Downloads/easyFL-main/venv/lib/python3.6/site-packages/pip/_internal/cli/req_command.py", line 203, in wrapper
#     return func(self, options, args)
#   File "/Users/hexiangyu/Downloads/easyFL-main/venv/lib/python3.6/site-packages/pip/_internal/commands/install.py", line 447, in run
#     options.target_dir, target_temp_dir, options.upgrade
#   File "/Users/hexiangyu/Downloads/easyFL-main/venv/lib/python3.6/site-packages/pip/_internal/commands/install.py", line 456, in _handle_target_dir
#     ensure_dir(target_dir)
#   File "/Users/hexiangyu/Downloads/easyFL-main/venv/lib/python3.6/site-packages/pip/_internal/utils/misc.py", line 110, in ensure_dir
#     os.makedirs(path)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/os.py", line 210, in makedirs
#     makedirs(head, mode, exist_ok)
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/os.py", line 220, in makedirs
#     mkdir(name, mode)
# OSError: [Errno 45] Operation not supported: '/home/aistudio'
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/hexiangyu/Downloads/easyFL-main/venv/bin/python -m pip install --upgrade pip' command.

# %%
# 同时添加如下代码, 这样每次环境(kernel)启动的时候只要运行下方代码即可:
# Also add the following code, so that every time the environment (kernel) starts, just run the following code:
import sys
sys.path.append('/home/aistudio/external-libraries')

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.

# %%
#!unzip data/data24982/VOC_MASK.zip -d masks

# %%
#!unzip DATA/DATA1/JPEGImages.zip -d new_data/test/

# %%
#!unzip data/data2019/dataset1.zip -d masks2

# %%
import shutil
import os
in_path = 'new_data/test/JPEGImages'
out_path='masks/VOC_MASK/JPEGImages/'
for filepath,dirnames,filenames in os.walk(in_path):   #在多级目录下找文件 
        for filename in filenames:
            str1 = filename.split('.')[0]
            str1_1 = filename.split('.')[1]
            if str1_1 == "jpg" or str1_1 == "jpeg" or str1_1 == "JPG" or str1_1 == "JPEG":
                shutil.copy(filepath + "/" + filename, out_path) #复制文件
                #shutil.move() 移动文件  
            else:
                continue

# %%
work_dir = 'masks2/dataset1/dataset1/Annotations'
new_dir='masks/VOC_MASK/Annotations/'
# masks/VOC_MASK/JPEGImages/1_Handshaking_Handshaking_1_341.jpg
for parent, dirnames, filenames in os.walk(work_dir,  followlinks=True):
        for filename in filenames:
            file_path = os.path.join(parent, filename)
            file = open(file_path,"r+",encoding='UTF-8')
            newFile = open(new_dir+filename,"w",encoding='UTF-8')
            for line in file.readlines():
                if("FIRC" in line):
                    line = line.replace("FIRC","Unknown")
                if("person" in line):
                    line = line.replace("person","not_standard")             
                newFile.writelines(line)
            print (filename)
            newFile.close()
            file.close()

# %%
import xml.etree.cElementTree as ET
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import math
import paddle.fluid as fluid
import myyolo3net as mynet
import time
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-c83343d67b61> in <module>
#       1 import xml.etree.cElementTree as ET
#       2 import os
# ----> 3 import cv2
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
xmlDir = r"masks/VOC_MASK/Annotations"
imgDir = r"masks/VOC_MASK/JPEGImages"
xmlList = [os.path.join(xmlDir, f) for f in os.listdir(xmlDir)]
labelDic = {'face': 0, 'face_mask': 1}
BATCH_SIZE = 16
imgSize = (448,448)  # w,h
iouLim = 0.1
# anchorBox = [(40, 160), (80, 210), (80, 400)]  # 前宽后高
anchorBox = [(40, 40), (120, 120), (220, 220)]  # 前宽后高
colNum = imgSize[1] // 32
rowNum = imgSize[0] // 32
anchorNum = len(anchorBox)
classNum = len(labelDic)
outDim = (5 + classNum) * anchorNum
learningRate = 1e-4
testSize=96
random.shuffle(xmlList)
xmlListTest=xmlList[-testSize:]
xmlList=xmlList[0:-testSize]


# 从xml读图片，标签
def loadXmlandImg(xmlDir, loadImg=False, imgDir=imgDir, resize=False):
    # 输出的size是一个元组（w，h），theObjs为列表，每一位是一个字典，键name->标签，键box->[xxyy]
    xml = ET.parse(xmlDir)
    size = (
        int(xml.find("size").find("width").text),
        int(xml.find("size").find("height").text)
    )

    objs = xml.findall("object")
    theObjs = []
    # 遍历每个物品框生成一堆字典
    for obj in objs:
        bndbox = obj.find("bndbox")
        boxXXYY = [int(bndbox.find("xmin").text), int(bndbox.find("xmax").text),
                   int(bndbox.find("ymin").text), int(bndbox.find("ymax").text)]
        if resize:
            boxXXYY[0] *= resize[0] / size[0]
            boxXXYY[1] *= resize[0] / size[0]
            boxXXYY[2] *= resize[1] / size[1]
            boxXXYY[3] *= resize[1] / size[1]
        theObjs.append({
            "label": labelDic[obj.find("name").text],
            "box": boxXXYY
        })
    # 选择是不是加载图片
    if loadImg:
        fileName = xml.find("filename").text
        fileName = os.path.join(imgDir, fileName)
        img = cv2.imread(fileName)
        if resize:
            img = cv2.resize(img, resize)
        img = (cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype("float32") / 255.0).transpose(2, 0, 1)
        return size, theObjs, img
    else:
        return size, theObjs




# 构造yolo3真实框，输入真实框和框数上限，输出一个（框数，4）的xywh数组
def yolo3GTBoxLabel(gtBoxes, resize,boxNum=50):
    # gtBoxes，一个字典，包含label:01234和box:[x,x,y,y]两个键值对
    # shape = d['shapes']

    thisLabel = [0 for i in range(boxNum)]
    gtBoxArr = [[0, 0, 0, 0] for i in range(boxNum)]

    # 遍历这个图的每一个真实框
    for i in range(min(len(gtBoxes),boxNum)):
        box = gtBoxes[i]
        points = box['box']
        x1 = points[0]
        x2 = points[1]
        y1 = points[2]
        y2 = points[3]
        label = box['label']
        gtx = (x1 + x2) / 2
        gty = (y1 + y2) / 2
        gtw = x2 - x1
        gth = y2 - y1
        gtBoxArr[i] = [gtx/resize[0], gty/resize[1], gtw/resize[0], gth/resize[1]]
        thisLabel[i] = label
    # print(gtBoxArr,thisLabel)
    return np.array(gtBoxArr, dtype="float32"), np.array(thisLabel, dtype="int32")


# s, o, i = loadXmlandImg(os.path.join(xmlDir, xmlList[0]), True, imgDir)
# print(i.shape)


# 定义画矩形框的程序
def draw_rectangle(bbox, currentAxis=None, edgecolor='k', facecolor='y', fill=False, linestyle='-'):
    # currentAxis，坐标轴，通过plt.gca()获取
    # bbox，边界框，包含四个数值的list， [x1, x2, y1, y2]
    # edgecolor，边框线条颜色
    # facecolor，填充颜色
    # fill, 是否填充
    # linestype，边框线型
    # patches.Rectangle需要传入左上角坐标、矩形区域的宽度、高度等参数
    if not currentAxis:
        currentAxis = plt.gca()
    rect = patches.Rectangle((bbox[0], bbox[2]), bbox[1] - bbox[0] + 1, bbox[3] - bbox[2] + 1, linewidth=1,
                             edgecolor=edgecolor, facecolor=facecolor, fill=fill, linestyle=linestyle)
    currentAxis.add_patch(rect)

def dataReader2(xmllist, img_size=imgSize):
    labels = []
    gtboxes = []
    imgs = []
    for i in xmllist:
        size, obj, img = loadXmlandImg(i, True, resize=img_size)
        imgs.append(img)
        # print(obj)
        box, label = yolo3GTBoxLabel(obj, resize=imgSize)
        labels.append(label)
        gtboxes.append(box)
    return np.array(gtboxes, dtype="float32"), np.array(labels, dtype="int32"), np.array(imgs, dtype="float32")


# 构建网络

maxGTbox = 50
inputImg = fluid.layers.data("image", shape=[None, 3, imgSize[1], imgSize[0]], dtype="float32")
# inputLabel = fluid.layers.data("label", shape=[None, anchorNum, 5 + classNum, rowNum, colNum], dtype="float32")
inputLabel = fluid.layers.data("label", shape=[None, maxGTbox], dtype="int32")
inputGtbox = fluid.layers.data("gtbox", shape=[None, maxGTbox, 4], dtype="float32")
(C0, C1, C2) = mynet.Darknet53(inputImg)  # 经过骨干网络提取特征
(r0, t0, P0) = mynet.yoloMain(C0, outDim)  # 得到yolo3的0级输出
r0_resize = fluid.layers.resize_nearest(input=r0, scale=2)
C1_New = fluid.layers.concat(input=[r0_resize, C1], axis=1)  # 和C1拼起来
(r1, t1, P1) = mynet.yoloMain(C1_New, outDim)  # yolo3的1级输出
r1_resize = fluid.layers.resize_nearest(input=r1, scale=2)
C1_New = fluid.layers.concat(input=[r1_resize, C2], axis=1)    # 和二级拼起来
(r2, t2, P2) = mynet.yoloMain(C1_New, outDim)
print(P0, P1, P2)

# lossAvg = mynet.yolo3LossNet(P0, inputLabel)
lossAll0 = fluid.layers.yolov3_loss(
    x=P0,
    gt_box=inputGtbox,
    gt_label=inputLabel,
    anchors=[7, 10, 12, 22, 24, 17,22, 45, 46, 33, 43, 88,85, 66, 115, 146, 275, 240],
    anchor_mask=[6,7,8],
    class_num=classNum,
    ignore_thresh=iouLim,
    downsample_ratio=32
)
lossAll1 = fluid.layers.yolov3_loss(
    x=P1,
    gt_box=inputGtbox,
    gt_label=inputLabel,
    anchors=[7, 10, 12, 22, 24, 17,22, 45, 46, 33, 43, 88,85, 66, 115, 146, 275, 240],
    anchor_mask=[3,4,5],
    class_num=classNum,
    ignore_thresh=iouLim,
    downsample_ratio=16
)
lossAll2 = fluid.layers.yolov3_loss(
    x=P2,
    gt_box=inputGtbox,
    gt_label=inputLabel,
    anchors=[7, 10, 12, 22, 24, 17,22, 45, 46, 33, 43, 88,85, 66, 115, 146, 275, 240],
    anchor_mask=[0, 1, 2],
    class_num=classNum,
    ignore_thresh=iouLim,
    downsample_ratio=8
)
lossAll = lossAll0 + lossAll1 + lossAll2
lossAvg = fluid.layers.mean(lossAll)
print(lossAvg)
testProgram = fluid.default_main_program().clone(for_test=True)
opt = fluid.optimizer.Momentum(
    learning_rate=fluid.layers.piecewise_decay(boundaries=[800,1500,4000], values=[1e-3,3e-4,1e-4,5e-5]),
    # learning_rate=1e-4,
    momentum=0.9,
    # regularization=fluid.regularizer.L2Decay(0.0005),
)
a=opt.minimize(lossAvg)
# 开始训练
# Out:
# name: "leaky_relu_423.tmp_0"
# type {
#   type: LOD_TENSOR
#   lod_tensor {
#     tensor {
#       data_type: FP32
#       dims: -1
#       dims: 21
#       dims: 14
#       dims: 14
#     }
#     lod_level: 0
#   }
# }
# persistable: false
#  name: "leaky_relu_430.tmp_0"
# type {
#   type: LOD_TENSOR
#   lod_tensor {
#     tensor {
#       data_type: FP32
#       dims: -1
#       dims: 21
#       dims: 28
#       dims: 28
#     }
#     lod_level: 0
#   }
# }
# persistable: false
#  name: "leaky_relu_437.tmp_0"
# type {
#   type: LOD_TENSOR
#   lod_tensor {
#     tensor {
#       data_type: FP32
#       dims: -1
#       dims: 21
#       dims: 56
#       dims: 56
#     }
#     lod_level: 0
#   }
# }
# persistable: false
#
# name: "mean_5.tmp_0"
# type {
#   type: LOD_TENSOR
#   lod_tensor {
#     tensor {
#       data_type: FP32
#       dims: 1
#     }
#   }
# }
# persistable: false
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_333/4002451906.py in <module>
#     171 lossAvg = fluid.layers.mean(lossAll)
#     172 print(lossAvg)
# --> 173 testProgram = fluid.default_main_program().clone(for_test=True)
#     174 opt = fluid.optimizer.Momentum(
#     175     learning_rate=fluid.layers.piecewise_decay(boundaries=[800,1500,4000], values=[1e-3,3e-4,1e-4,5e-5]),
#
# </opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/decorator.py:decorator-gen-140> in clone(self, for_test)
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/wrapped_decorator.py in __impl__(func, *args, **kwargs)
#      23     def __impl__(func, *args, **kwargs):
#      24         wrapped_func = decorator_func(func)
# ---> 25         return wrapped_func(*args, **kwargs)
#      26
#      27     return __impl__
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/framework.py in __impl__(*args, **kwargs)
#     196         assert not in_dygraph_mode(
#     197         ), "We don't support %s in Dygraph mode" % func.__name__
# --> 198         return func(*args, **kwargs)
#     199
#     200     return __impl__
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/framework.py in clone(self, for_test)
#    4016             p._sync_with_cpp()
#    4017
# -> 4018         p._copy_param_info_from(self)
#    4019         p._copy_data_info_from(self)
#    4020         p._copy_dist_param_info_from(self)
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/framework.py in _copy_param_info_from(self, other)
#    4444
#    4445         if len(self.blocks) != len(other.blocks):
# -> 4446             raise ValueError("_copy_param_info_from should be invoked with two "
#    4447                              "program, with represent the same topology")
#    4448         self.global_block()._copy_param_info_from(other.global_block())
#
# ValueError: _copy_param_info_from should be invoked with two program, with represent the same topology

# %%
print("开始编译网络")
initPro = fluid.default_startup_program()
mainProg = fluid.default_main_program()

# place = fluid.CPUPlace()
place = fluid.CUDAPlace(0)
exe = fluid.Executor(place)
exe.run(program=initPro)

def testModel():
    miniBatch=4
    begin=0
    end=miniBatch
    lossAll=0.0
    while end<=testSize:
        b, l, ii = dataReader2(xmlListTest[begin:end])
        lo=exe.run(testProgram,
        feed={
                    'image': ii,
                    "label": l,
                    'gtbox': b
        },
        fetch_list=[lossAvg]
        )
        lossAll+=lo[0]
        print(lo[0])
        begin+=miniBatch
        end+=miniBatch
    print("损失：",lossAll/(testSize//miniBatch))
# Out:
# 开始编译网络

# %%
# !cd
fluid.io.load_persistables(exe,'./model', mainProg)

print("开始训练")
dataNum = len(xmlList)
for i in range(5):
    testModel()
    random.shuffle(xmlList)
    tic = time.time()
    begin = 0
    end = BATCH_SIZE
    while end <= dataNum:
        b, l, ii = dataReader2(xmlList[begin:end])
        # print(b.shape, l.shape, i.shape)
        for j in range(1):
            la = exe.run(
                program=mainProg,
                feed={
                    'image': ii,
                    "label": l,
                    'gtbox': b
                },
                fetch_list=[lossAvg]
            )
        # print(la)
        if begin%1024==0:
            print(i,begin,la, time.time() - tic)
        begin += BATCH_SIZE
        end += BATCH_SIZE

# b, l, i = dataReader2(xmlList[0:1])

# print(b.shape, l.shape, i.shape)
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/executor.py:789: UserWarning: The following exception is not an EOF exception.
#   "The following exception is not an EOF exception.")
# ---------------------------------------------------------------------------
# EnforceNotMet                             Traceback (most recent call last)
# /tmp/ipykernel_333/1423490736.py in <module>
#       1 get_ipython().system('cd')
# ----> 2 fluid.io.load_persistables(exe,'./model', mainProg)
#       3
#       4 print("开始训练")
#       5 dataNum = len(xmlList)
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/io.py in load_persistables(executor, dirname, main_program, filename)
#     914             main_program=main_program,
#     915             predicate=is_persistable,
# --> 916             filename=filename)
#     917
#     918
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/io.py in load_vars(executor, dirname, main_program, vars, predicate, filename)
#     739             main_program=main_program,
#     740             vars=list(filter(predicate, main_program.list_vars())),
# --> 741             filename=filename)
#     742     else:
#     743         load_prog = Program()
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/io.py in load_vars(executor, dirname, main_program, vars, predicate, filename)
#     791                     'model_from_memory': vars_from_memory
#     792                 })
# --> 793         executor.run(load_prog)
#     794
#     795         # check var shape
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/executor.py in run(self, program, feed, fetch_list, feed_var_name, fetch_var_name, scope, return_numpy, use_program_cache)
#     788                 warnings.warn(
#     789                     "The following exception is not an EOF exception.")
# --> 790             six.reraise(*sys.exc_info())
#     791
#     792     def _run_impl(self, program, feed, fetch_list, feed_var_name,
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/executor.py in run(self, program, feed, fetch_list, feed_var_name, fetch_var_name, scope, return_numpy, use_program_cache)
#     783                 scope=scope,
#     784                 return_numpy=return_numpy,
# --> 785                 use_program_cache=use_program_cache)
#     786         except Exception as e:
#     787             if not isinstance(e, core.EOFException):
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/executor.py in _run_impl(self, program, feed, fetch_list, feed_var_name, fetch_var_name, scope, return_numpy, use_program_cache)
#     836                 scope=scope,
#     837                 return_numpy=return_numpy,
# --> 838                 use_program_cache=use_program_cache)
#     839
#     840         program._compile(scope, self.place)
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/executor.py in _run_program(self, program, feed, fetch_list, feed_var_name, fetch_var_name, scope, return_numpy, use_program_cache)
#     910         if not use_program_cache:
#     911             self._default_executor.run(program.desc, scope, 0, True, True,
# --> 912                                        fetch_var_name)
#     913         else:
#     914             self._default_executor.run_prepared_ctx(ctx, scope, False, False,
#
# EnforceNotMet:
#
# --------------------------------------------
# C++ Call Stacks (More useful to developers):
# --------------------------------------------
# 0   std::string paddle::platform::GetTraceBackString<char const*>(char const*&&, char const*, int)
# 1   paddle::platform::EnforceNotMet::EnforceNotMet(std::__exception_ptr::exception_ptr, char const*, int)
# 2   paddle::operators::LoadOpKernel<paddle::platform::CUDADeviceContext, float>::Compute(paddle::framework::ExecutionContext const&) const
# 3   std::_Function_handler<void (paddle::framework::ExecutionContext const&), paddle::framework::OpKernelRegistrarFunctor<paddle::platform::CUDAPlace, false, 0ul, paddle::operators::LoadOpKernel<paddle::platform::CUDADeviceContext, float>, paddle::operators::LoadOpKernel<paddle::platform::CUDADeviceContext, double>, paddle::operators::LoadOpKernel<paddle::platform::CUDADeviceContext, int>, paddle::operators::LoadOpKernel<paddle::platform::CUDADeviceContext, signed char>, paddle::operators::LoadOpKernel<paddle::platform::CUDADeviceContext, long> >::operator()(char const*, char const*, int) const::{lambda(paddle::framework::ExecutionContext const&)#1}>::_M_invoke(std::_Any_data const&, paddle::framework::ExecutionContext const&)
# 4   paddle::framework::OperatorWithKernel::RunImpl(paddle::framework::Scope const&, paddle::platform::Place const&, paddle::framework::RuntimeContext*) const
# 5   paddle::framework::OperatorWithKernel::RunImpl(paddle::framework::Scope const&, paddle::platform::Place const&) const
# 6   paddle::framework::OperatorBase::Run(paddle::framework::Scope const&, paddle::platform::Place const&)
# 7   paddle::framework::Executor::RunPreparedContext(paddle::framework::ExecutorPrepareContext*, paddle::framework::Scope*, bool, bool, bool)
# 8   paddle::framework::Executor::Run(paddle::framework::ProgramDesc const&, paddle::framework::Scope*, int, bool, bool, std::vector<std::string, std::allocator<std::string> > const&, bool, bool)
#
# ------------------------------------------
# Python Call Stacks (More useful to users):
# ------------------------------------------
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/framework.py", line 2525, in append_op
#     attrs=kwargs.get("attrs", None))
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/io.py", line 773, in load_vars
#     attrs={'file_path': os.path.join(dirname, new_var.name)})
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/io.py", line 741, in load_vars
#     filename=filename)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/io.py", line 916, in load_persistables
#     filename=filename)
#   File "/tmp/ipykernel_333/1423490736.py", line 2, in <module>
#     fluid.io.load_persistables(exe,'./model', mainProg)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3173, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2902, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 353, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 648, in execute_request
#     reply_content = await reply_content
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 353, in dispatch_shell
#     await result
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 446, in process_one
#     await dispatch(*args)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 457, in dispatch_queue
#     await self.process_one()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#
# ----------------------
# Error Message Summary:
# ----------------------
# Error: Cannot open file model/conv2d_73.w_0 for load op at (/paddle/paddle/fluid/operators/load_op.h:38)
#   [operator < load > error]

# %%
# 保存模型
fluid.io.save_persistables(exe, './model', fluid.default_main_program())

# %%
# 保存预测模型
fluid.io.save_inference_model("./refMaskModel/",
                              feeded_var_names=['image'],
                              target_vars=[P0,P1,P2],
                              executor=exe)

# %%
# 打包下载
# !zip -r refMaskModel6.zip refMaskModel
# Out:
#   adding: refMaskModel/ (stored 0%)
#   adding: refMaskModel/batch_norm_8.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_67.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_58.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_42.w_2 (deflated 13%)
#   adding: refMaskModel/batch_norm_49.w_2 (deflated 14%)
#   adding: refMaskModel/conv2d_9.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_17.w_1 (deflated 2%)
#   adding: refMaskModel/batch_norm_27.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_64.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_50.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_63.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_19.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_32.w_0 (deflated 5%)
#   adding: refMaskModel/conv2d_20.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_58.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_40.w_1 (deflated 6%)
#   adding: refMaskModel/conv2d_4.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_36.w_0 (deflated 5%)
#   adding: refMaskModel/conv2d_71.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_13.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_61.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_37.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_60.w_2 (deflated 10%)
#   adding: refMaskModel/conv2d_19.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_5.w_0 (stored 0%)
#   adding: refMaskModel/conv2d_35.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_28.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_53.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_7.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_27.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_4.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_31.w_0 (deflated 3%)
#   adding: refMaskModel/conv2d_2.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_6.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_1.w_2 (deflated 0%)
#   adding: refMaskModel/conv2d_28.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_26.w_1 (deflated 5%)
#   adding: refMaskModel/conv2d_23.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_6.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_1.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_62.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_20.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_63.b_0 (deflated 5%)
#   adding: refMaskModel/conv2d_52.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_24.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_40.w_2 (deflated 13%)
#   adding: refMaskModel/__model__ (deflated 98%)
#   adding: refMaskModel/batch_norm_28.w_2 (deflated 9%)
#   adding: refMaskModel/batch_norm_22.w_2 (deflated 0%)
#   adding: refMaskModel/batch_norm_57.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_35.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_48.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_60.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_68.w_1 (deflated 5%)
#   adding: refMaskModel/conv2d_68.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_49.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_6.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_20.w_1 (stored 0%)
#   adding: refMaskModel/conv2d_43.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_54.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_59.w_2 (deflated 9%)
#   adding: refMaskModel/conv2d_62.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_21.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_19.w_1 (deflated 2%)
#   adding: refMaskModel/batch_norm_10.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_30.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_65.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_0.w_2 (deflated 5%)
#   adding: refMaskModel/batch_norm_21.w_2 (deflated 7%)
#   adding: refMaskModel/conv2d_72.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_69.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_2.w_1 (deflated 4%)
#   adding: refMaskModel/batch_norm_61.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_4.w_2 (stored 0%)
#   adding: refMaskModel/batch_norm_30.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_10.w_2 (deflated 1%)
#   adding: refMaskModel/conv2d_70.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_25.w_1 (deflated 2%)
#   adding: refMaskModel/batch_norm_43.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_52.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_50.w_2 (deflated 13%)
#   adding: refMaskModel/batch_norm_62.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_34.w_0 (deflated 5%)
#   adding: refMaskModel/conv2d_65.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_11.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_33.w_1 (deflated 3%)
#   adding: refMaskModel/conv2d_40.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_66.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_6.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_1.w_1 (stored 0%)
#   adding: refMaskModel/conv2d_56.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_65.w_2 (deflated 8%)
#   adding: refMaskModel/conv2d_39.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_14.w_2 (deflated 1%)
#   adding: refMaskModel/conv2d_26.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_46.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_41.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_39.b_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_65.b_0 (deflated 8%)
#   adding: refMaskModel/batch_norm_9.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_5.w_2 (deflated 0%)
#   adding: refMaskModel/conv2d_51.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_47.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_21.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_37.w_1 (deflated 3%)
#   adding: refMaskModel/conv2d_5.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_59.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_12.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_10.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_70.b_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_26.w_0 (deflated 5%)
#   adding: refMaskModel/conv2d_16.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_33.b_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_43.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_9.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_18.w_2 (deflated 0%)
#   adding: refMaskModel/conv2d_15.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_64.w_2 (deflated 9%)
#   adding: refMaskModel/batch_norm_46.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_70.w_1 (deflated 4%)
#   adding: refMaskModel/batch_norm_62.w_2 (deflated 9%)
#   adding: refMaskModel/batch_norm_25.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_9.w_1 (deflated 2%)
#   adding: refMaskModel/batch_norm_2.w_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_72.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_35.w_2 (deflated 9%)
#   adding: refMaskModel/conv2d_60.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_20.w_2 (deflated 2%)
#   adding: refMaskModel/batch_norm_29.b_0 (deflated 4%)
#   adding: refMaskModel/conv2d_67.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_25.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_14.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_16.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_39.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_58.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_53.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_34.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_43.b_0 (deflated 8%)
#   adding: refMaskModel/batch_norm_57.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_50.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_41.b_0 (deflated 3%)
#   adding: refMaskModel/conv2d_53.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_34.b_0 (deflated 7%)
#   adding: refMaskModel/conv2d_12.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_58.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_23.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_9.w_2 (deflated 5%)
#   adding: refMaskModel/batch_norm_11.w_1 (deflated 2%)
#   adding: refMaskModel/conv2d_58.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_49.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_68.b_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_38.w_2 (deflated 13%)
#   adding: refMaskModel/batch_norm_45.b_0 (deflated 8%)
#   adding: refMaskModel/conv2d_31.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_60.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_23.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_42.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_36.w_2 (deflated 13%)
#   adding: refMaskModel/batch_norm_43.w_2 (deflated 13%)
#   adding: refMaskModel/batch_norm_51.w_2 (deflated 14%)
#   adding: refMaskModel/batch_norm_4.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_38.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_44.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_54.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_64.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_69.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_54.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_16.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_50.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_55.w_2 (deflated 11%)
#   adding: refMaskModel/conv2d_29.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_8.w_2 (deflated 0%)
#   adding: refMaskModel/batch_norm_16.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_3.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_17.w_2 (deflated 6%)
#   adding: refMaskModel/conv2d_17.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_15.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_52.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_61.w_2 (deflated 9%)
#   adding: refMaskModel/batch_norm_18.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_25.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_16.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_1.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_7.w_1 (stored 0%)
#   adding: refMaskModel/conv2d_57.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_42.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_66.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_40.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_41.w_2 (deflated 8%)
#   adding: refMaskModel/conv2d_37.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_33.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_48.b_0 (deflated 7%)
#   adding: refMaskModel/conv2d_54.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_45.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_34.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_33.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_31.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_54.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_13.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_60.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_6.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_53.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_24.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_55.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_67.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_67.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_7.w_2 (deflated 0%)
#   adding: refMaskModel/conv2d_32.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_31.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_36.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_47.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_67.b_0 (deflated 6%)
#   adding: refMaskModel/conv2d_44.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_72.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_17.w_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_42.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_66.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_55.b_0 (deflated 7%)
#   adding: refMaskModel/conv2d_41.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_22.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_71.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_37.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_24.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_66.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_24.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_45.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_47.w_2 (deflated 13%)
#   adding: refMaskModel/batch_norm_71.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_23.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_19.w_2 (deflated 5%)
#   adding: refMaskModel/batch_norm_26.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_28.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_18.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_12.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_2.w_2 (deflated 5%)
#   adding: refMaskModel/batch_norm_8.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_59.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_19.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_47.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_0.w_0 (deflated 3%)
#   adding: refMaskModel/conv2d_46.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_57.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_51.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_49.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_36.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_46.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_69.w_2 (deflated 9%)
#   adding: refMaskModel/conv2d_69.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_27.w_1 (deflated 3%)
#   adding: refMaskModel/conv2d_10.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_35.b_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_47.w_0 (deflated 6%)
#   adding: refMaskModel/conv2d_3.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_39.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_41.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_56.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_59.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_3.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_40.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_0.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_70.w_0 (deflated 4%)
#   adding: refMaskModel/batch_norm_22.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_56.w_2 (deflated 10%)
#   adding: refMaskModel/batch_norm_57.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_3.w_1 (deflated 0%)
#   adding: refMaskModel/batch_norm_5.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_52.w_2 (deflated 11%)
#   adding: refMaskModel/conv2d_36.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_11.w_2 (deflated 4%)
#   adding: refMaskModel/conv2d_48.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_55.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_15.w_0 (deflated 3%)
#   adding: refMaskModel/conv2d_61.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_56.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_46.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_12.w_2 (deflated 1%)
#   adding: refMaskModel/batch_norm_12.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_71.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_48.w_2 (deflated 13%)
#   adding: refMaskModel/batch_norm_52.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_32.w_1 (deflated 6%)
#   adding: refMaskModel/batch_norm_27.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_10.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_68.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_70.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_15.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_28.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_5.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_72.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_53.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_63.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_20.b_0 (stored 0%)
#   adding: refMaskModel/conv2d_8.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_2.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_29.w_0 (deflated 2%)
#   adding: refMaskModel/conv2d_14.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_14.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_0.b_0 (deflated 3%)
#   adding: refMaskModel/conv2d_55.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_38.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_30.w_0 (deflated 7%)
#   adding: refMaskModel/conv2d_24.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_51.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_3.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_25.w_2 (deflated 6%)
#   adding: refMaskModel/batch_norm_44.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_17.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_13.w_2 (deflated 6%)
#   adding: refMaskModel/conv2d_27.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_38.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_32.b_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_31.w_1 (deflated 3%)
#   adding: refMaskModel/conv2d_49.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_29.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_44.b_0 (deflated 6%)
#   adding: refMaskModel/conv2d_64.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_18.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_13.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_22.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_30.w_2 (deflated 10%)
#   adding: refMaskModel/conv2d_18.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_23.w_1 (deflated 2%)
#   adding: refMaskModel/conv2d_0.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_48.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_13.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_69.w_0 (deflated 6%)
#   adding: refMaskModel/conv2d_42.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_61.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_8.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_26.b_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_14.w_0 (stored 0%)
#   adding: refMaskModel/batch_norm_44.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_11.b_0 (deflated 3%)
#   adding: refMaskModel/batch_norm_38.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_66.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_45.w_2 (deflated 11%)
#   adding: refMaskModel/batch_norm_30.b_0 (deflated 7%)
#   adding: refMaskModel/conv2d_50.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_7.b_0 (stored 0%)
#   adding: refMaskModel/batch_norm_15.b_0 (deflated 3%)
#   adding: refMaskModel/conv2d_7.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_11.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_72.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_62.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_32.w_2 (deflated 10%)
#   adding: refMaskModel/batch_norm_34.w_2 (deflated 12%)
#   adding: refMaskModel/batch_norm_64.w_0 (deflated 6%)
#   adding: refMaskModel/batch_norm_51.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_56.w_1 (deflated 5%)
#   adding: refMaskModel/batch_norm_37.w_2 (deflated 8%)
#   adding: refMaskModel/batch_norm_65.w_1 (deflated 7%)
#   adding: refMaskModel/conv2d_1.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_33.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_45.w_1 (deflated 7%)
#   adding: refMaskModel/batch_norm_68.w_0 (deflated 5%)
#   adding: refMaskModel/batch_norm_71.w_2 (deflated 7%)
#   adding: refMaskModel/conv2d_59.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_21.w_0 (deflated 2%)
#   adding: refMaskModel/batch_norm_39.w_1 (deflated 3%)
#   adding: refMaskModel/batch_norm_4.w_1 (stored 0%)
#   adding: refMaskModel/batch_norm_29.w_2 (deflated 7%)
#   adding: refMaskModel/batch_norm_21.w_1 (deflated 3%)
#   adding: refMaskModel/conv2d_22.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_35.w_1 (deflated 3%)
#   adding: refMaskModel/conv2d_63.w_0 (deflated 7%)
#   adding: refMaskModel/batch_norm_63.w_1 (deflated 6%)

# %%
# 预测模型
import cv2
import numpy as np
import paddle.fluid as fluid
import time
import matplotlib.pyplot as plt
import math
import matplotlib.patches as patches

print("开始运行")

fluid.Scope()

## 加载所有文件的路径，每个文件在数组中有一位
modelPath = r'refMaskModel'
dataMap = {'face': 0, 'face_mask': 1,'not_standard':2}
classNum = 3
limObj = 0.8
iouLim=0.1

## 加载模型
place = fluid.CUDAPlace(0)
mainProg = fluid.default_main_program()
exe = fluid.Executor(place)

[inference_program,  # 预测用的program
 feed_target_names,  # 一个str列表，它包含需要在预测 Program 中提供数据的变量的名称。
 fetch_targets] = fluid.io.load_inference_model(
    modelPath,
    exe
)


# 测试模型

def loadImg(path):
    img = cv2.imread(path)
    # print(img)
    img = cv2.resize(img, (448, 448), interpolation=cv2.INTER_AREA)
    img = (cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype("float32") / 255.0).transpose(2, 0, 1)
    return np.array([img], dtype="float32")


def sigma(x):
    return 1 / (1 + math.exp(-x))


def draw_rectangle(bbox, currentAxis=None, edgecolor='k', facecolor='y', fill=False, linestyle='-'):
    # currentAxis，坐标轴，通过plt.gca()获取
    # bbox，边界框，包含四个数值的list， [x1, x2, y1, y2]
    # edgecolor，边框线条颜色
    # facecolor，填充颜色
    # fill, 是否填充
    # linestype，边框线型
    # patches.Rectangle需要传入左上角坐标、矩形区域的宽度、高度等参数
    if not currentAxis:
        currentAxis = plt.gca()
    rect = patches.Rectangle((bbox[0], bbox[2]), bbox[1] - bbox[0] + 1, bbox[3] - bbox[2] + 1, linewidth=1,
                             edgecolor=edgecolor, facecolor=facecolor, fill=fill, linestyle=linestyle)
    currentAxis.add_patch(rect)


def getIOU(xxyy1, xxyy2):
    x2 = min(xxyy1[1], xxyy2[1])
    x1 = max(xxyy1[0], xxyy2[0])
    y1 = max(xxyy1[2], xxyy2[2])
    y2 = min(xxyy1[3], xxyy2[3])

    if (x2 < x1) or (y1 > y2):
        return 0.0
    else:
        i = (x2 - x1) * (y2 - y1)
        s1 = (xxyy1[1] - xxyy1[0]) * (xxyy1[3] - xxyy1[2])
        s2 = (xxyy2[1] - xxyy2[0]) * (xxyy2[3] - xxyy2[2])
        return i / (s1 + s2 - i)


def refImg(imgPath):
    # maybeBox = [[] for i in range(classNum)]
    maybeBox = []
    img = loadImg(imgPath)

    def logBox(pred, stride, archors):
        pred0_ = pred[0]
        archorNum = len(archors) // 2
        for i in range(pred0_.shape[1]):
            for j in range(pred0_.shape[2]):
                for p in range(archorNum):
                    if sigma(pred0_[4 + p * (5 + classNum), i, j]) > limObj:
                        res = pred0_[p * (5 + classNum):(p + 1) * (5 + classNum), i, j]
                        x = stride * (j + sigma(res[0]))
                        y = stride * (i + sigma(res[1]))
                        w = archors[p * 2] * math.exp(res[2])
                        h = archors[p * 2 + 1] * math.exp(res[3])
                        # max_ = (-1000)
                        # maxClass = -1
                        # 比较是脸还是口罩
                        if res[5] > res[6]:
                            maxClass = 0
                        else:
                            maxClass = 1

                        # for c in range(5, 5 + classNum):
                        #     if res[c] > max_:
                        #         max_ = res[c]
                        #         maxClass = c - 5

                        maybeBox.append({
                            "bbox": [x - w / 2, x + w / 2, y - h / 2, y + h / 2],
                            "obj": sigma(res[5 + maxClass]),
                            "state": 0,
                            "class": maxClass,
                            "stride": stride
                        })

    tic = time.time()
    pred0, pred1, pred2 = exe.run(
        program=inference_program,
        feed={feed_target_names[0]: img},
        fetch_list=fetch_targets
    )
    print(time.time() - tic)
    logBox(pred0, stride=32, archors=[85, 66, 115, 146, 275, 240])
    logBox(pred1, stride=16, archors=[22, 45, 46, 33, 43, 88])
    logBox(pred2, stride=8, archors=[7, 10, 12, 22, 24, 17])
    # print(maybeBox)
    plt.imshow(img[0].transpose(1, 2, 0))
    # goodBox0 = [[] for i in range(classNum)]
    # 去除多余的框
    # for i in range(classNum):
    while True:
        finish = True
        max_ = -1
        maxBox = 0
        for box in maybeBox:
            if box["state"] == 0 and box["obj"] > max_:
                finish = False
                max_ = box["obj"]
                maxBox = box
        if not finish:
            maxBox["state"] = 2
        for box in maybeBox:
            if box["state"] == 0 and getIOU(box["bbox"], maxBox["bbox"]) > 0.1:
                box["state"] = 1
        if finish:
            break

    # print("face")
    for box in maybeBox:
        if box["state"] == 2:
            print(box)
            if box["class"] == 0:
                draw_rectangle(box["bbox"], edgecolor='r')
            else:
                draw_rectangle(box["bbox"])

    # print("facemask")
    # for box in maybeBox[1]:
    #     if box["state"] == 2:
    #         print(box)
    #         draw_rectangle(box["bbox"])

    plt.show()


refImg(r"masks/VOC_MASK/JPEGImages/1_Handshaking_Handshaking_1_341.jpg")

# %%
# for i in range(1,15):
#     refImg("mymask/%d.jpg"%i)
