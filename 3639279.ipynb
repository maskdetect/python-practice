# %% [markdown]
# # **任务描述：**
#
# ### 本次实践是一个多分类任务，需要将照片中的宝石分别进行识别，完成**宝石的识别**
#
# ### **实践平台：百度AI实训平台-AI Studio、PaddlePaddle1.8.0 动态图**
#
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/7640d4434f894f5dbae1d85c62e54b8476e24856aabc4c5f9915fea1b26f3ebc)

# %% [markdown]
# # 深度神经网络(DNN)
#
# ### **深度神经网络（Deep Neural Networks，简称DNN）是深度学习的基础，其结构为input、hidden（可有多层）、output，每层均为全连接。**
# ![](https://ai-studio-static-online.cdn.bcebos.com/c60fc28848cf469fa3a7824aa637a03f3b2b213ce7b84659919cb24b4430bffb)

# %% [markdown]
# # 数据集介绍
#
# * **数据集文件名为archive_train.zip,archive_test.zip。**
#
# * **该数据集包含25个类别不同宝石的图像。**
#
# * **这些类别已经分为训练和测试数据。**
#
# * **图像大小不一，格式为.jpeg。**
#
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/7640d4434f894f5dbae1d85c62e54b8476e24856aabc4c5f9915fea1b26f3ebc)

# %%
# 查看当前挂载的数据集目录, 该目录下的变更重启环境后会自动还原
# View dataset directory. This directory will be recovered automatically after resetting environment. 
# !ls /home/aistudio/data
# Out:
# data55032  dataset

# %%
#导入需要的包
import os
import zipfile
import random
import json
import cv2
import numpy as np
from PIL import Image
import paddle
import paddle.fluid as fluid
from paddle.fluid.dygraph import Linear
import matplotlib.pyplot as plt
# Out:
# 2022-01-18 17:23:03,203-INFO: font search path ['/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf', '/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/afm', '/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts']
# 2022-01-18 17:23:03,646-INFO: generated new fontManager

# %% [markdown]
# # 1、数据准备

# %%
'''
参数配置
'''
train_parameters = {
    "input_size": [3, 64, 64],                           #输入图片的shape
    "class_dim": -1,                                     #分类数
    'augment_path' : '/home/aistudio/augment',           #数据增强图片目录
    "src_path":"data/data55032/archive_train.zip",       #原始数据集路径
    "target_path":"/home/aistudio/data/dataset",        #要解压的路径 
    "train_list_path": "./train_data.txt",              #train_data.txt路径
    "eval_list_path": "./val_data.txt",                  #eval_data.txt路径
    "label_dict":{},                                    #标签字典
    "readme_path": "/home/aistudio/data/readme.json",   #readme.json路径
    "num_epochs": 20,                                    #训练轮数
    "train_batch_size": 64,                             #批次的大小
    "learning_strategy": {                              #优化函数相关的配置
        "lr": 0.001                                     #超参数学习率
    } 
}

# %%
def unzip_data(src_path,target_path):

    '''
    解压原始数据集，将src_path路径下的zip包解压至data/dataset目录下
    '''

    if(not os.path.isdir(target_path)):    
        z = zipfile.ZipFile(src_path, 'r')
        z.extractall(path=target_path)
        z.close()
    else:
        print("文件已解压")

# %%
def get_data_list(target_path,train_list_path,eval_list_path, augment_path):
    '''
    生成数据列表
    '''
    #存放所有类别的信息
    class_detail = []
    #获取所有类别保存的文件夹名称
    data_list_path=target_path
    class_dirs = os.listdir(data_list_path)
    if '__MACOSX' in class_dirs:
        class_dirs.remove('__MACOSX')
    # #总的图像数量
    all_class_images = 0
    # #存放类别标签
    class_label=0
    # #存放类别数目
    class_dim = 0
    # #存储要写进eval.txt和train.txt中的内容
    trainer_list=[]
    eval_list=[]
    #读取每个类别
    for class_dir in class_dirs:
        if class_dir != ".DS_Store":
            class_dim += 1
            #每个类别的信息
            class_detail_list = {}
            eval_sum = 0
            trainer_sum = 0
            #统计每个类别有多少张图片
            class_sum = 0
            #获取类别路径 
            path = os.path.join(data_list_path,class_dir)
            # print(path)
            # 获取所有图片
            img_paths = os.listdir(path)
            for img_path in img_paths:                                  # 遍历文件夹下的每个图片
                if img_path =='.DS_Store':
                    continue
                name_path = os.path.join(path,img_path)                       # 每张图片的路径
                if class_sum % 15 == 0:                                 # 每10张图片取一个做验证数据
                    eval_sum += 1                                       # eval_sum为测试数据的数目
                    eval_list.append(name_path + "\t%d" % class_label + "\n")
                else:
                    trainer_sum += 1 
                    trainer_list.append(name_path + "\t%d" % class_label + "\n")#trainer_sum测试数据的数目
                class_sum += 1                                          #每类图片的数目
                all_class_images += 1                                   #所有类图片的数目 
            # ----------------------------------数据增强----------------------------------
            aug_path = os.path.join(augment_path, class_dir)
            for img_path in os.listdir(aug_path):                                  # 遍历文件夹下的每个图片
                name_path = os.path.join(aug_path,img_path)                       # 每张图片的路径
                trainer_sum += 1 
                trainer_list.append(name_path + "\t%d" % class_label + "\n")#trainer_sum测试数据的数目
                all_class_images += 1                                   #所有类图片的数目
            # ----------------------------------------------------------------------------
            # 说明的json文件的class_detail数据
            class_detail_list['class_name'] = class_dir             #类别名称
            class_detail_list['class_label'] = class_label          #类别标签
            class_detail_list['class_eval_images'] = eval_sum       #该类数据的测试集数目
            class_detail_list['class_trainer_images'] = trainer_sum #该类数据的训练集数目
            class_detail.append(class_detail_list)  
            #初始化标签列表
            train_parameters['label_dict'][str(class_label)] = class_dir
            class_label += 1
            
    #初始化分类数
    train_parameters['class_dim'] = class_dim
    print(train_parameters)
    #乱序  
    random.shuffle(eval_list)
    with open(eval_list_path, 'a') as f:
        for eval_image in eval_list:
            f.write(eval_image) 
    #乱序        
    random.shuffle(trainer_list) 
    with open(train_list_path, 'a') as f2:
        for train_image in trainer_list:
            f2.write(train_image) 

    # 说明的json文件信息
    readjson = {}
    readjson['all_class_name'] = data_list_path                  #文件父目录
    readjson['all_class_images'] = all_class_images
    readjson['class_detail'] = class_detail
    jsons = json.dumps(readjson, sort_keys=True, indent=4, separators=(',', ': '))
    with open(train_parameters['readme_path'],'w') as f:
        f.write(jsons)
    print ('生成数据列表完成！')

# %%
def data_reader(file_list):
    '''
    自定义data_reader
    '''
    def reader():
        with open(file_list, 'r') as f:
            lines = [line.strip() for line in f]
            for line in lines:
                img_path, lab = line.strip().split('\t')
                img = Image.open(img_path) 
                if img.mode != 'RGB': 
                    img = img.convert('RGB') 
                img = img.resize((64, 64), Image.BILINEAR)
                img = np.array(img).astype('float32') 
                img = img.transpose((2, 0, 1))  # HWC to CHW 
                img = img/255                   # 像素值归一化 
                yield img, int(lab) 
    return reader

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting Augmentor
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/93/6e/1911e5117a4e7c3f99ade92b34ed7372739a3e7b977c62e4e90f039a95d1/Augmentor-0.2.9-py2.py3-none-any.whl
# Requirement already satisfied: Pillow>=5.2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from Augmentor) (4.36.1)
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from Augmentor) (1.16.4)
# Requirement already satisfied: future>=0.16.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from Augmentor) (0.18.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.9

# %%
'''
参数初始化
'''
src_path=train_parameters['src_path']
target_path=train_parameters['target_path']
train_list_path=train_parameters['train_list_path']
eval_list_path=train_parameters['eval_list_path']
batch_size=train_parameters['train_batch_size']
augment_path = train_parameters['augment_path']
'''
解压原始数据到指定路径
'''
unzip_data(src_path,target_path)

# %%
def proc_img(src):
    for root, dirs, files in os.walk(src):
        if '__MACOSX' in root:continue
        for file in files:            
            src=os.path.join(root,file)
            img=Image.open(src)
            if img.mode != 'RGB': 
                    img = img.convert('RGB') 
                    img.save(src)            


if __name__=='__main__':
    proc_img(r"data/dataset")

# %%
import os, Augmentor
import shutil, glob

if not os.path.exists(augment_path): # 控制不重复增强数据
    for root, dirs, files in os.walk("data/dataset", topdown=False):
        print(root,dirs,files,'1')
        for name in dirs:
            path_ = os.path.join(root, name)
            if '__MACOSX' in path_:continue
            print('数据增强：',os.path.join(root, name))
            print('image：',os.path.join(root, name))
            p = Augmentor.Pipeline(os.path.join(root, name),output_directory='output')
            p.rotate(probability=0.6, max_left_rotation=2, max_right_rotation=2)
            p.zoom(probability=0.6, min_factor=0.9, max_factor=1.1)
            p.random_distortion(probability=0.4, grid_height=2, grid_width=2, magnitude=1)

            count = 1000 - len(glob.glob(pathname=path_+'/*.jpg'))
            p.sample(count, multi_threaded=False)
            p.process()

    print('将生成的图片拷贝到正确的目录')
    for root, dirs, files in os.walk("data/dataset", topdown=False):
        for name in files:
            path_ = os.path.join(root, name)
            if path_.rsplit('/',3)[2] == 'output':
                type_ = path_.rsplit('/',3)[1]
                dest_dir = os.path.join(augment_path ,type_) 
                if not os.path.exists(dest_dir):os.makedirs(dest_dir) 
                dest_path_ = os.path.join(augment_path ,type_, name) 
                shutil.move(path_, dest_path_)
    print('删除所有output目录')
    for root, dirs, files in os.walk("data/dataset", topdown=False):
        for name in dirs:
            if name == 'output':
                path_ = os.path.join(root, name)
                shutil.rmtree(path_)
    print('完成数据增强')
# Out:
# Processing emerald_21.jpg:   1%|          | 9/964 [00:00<00:19, 48.04 Samples/s]
# data/dataset/Emerald [] ['emerald_23.jpg', 'emerald_38.jpg', 'emerald_25.jpg', 'emerald_27.jpg', 'emerald_0.jpg', 'emerald_2.jpg', 'emerald_19.jpg', 'emerald_6.jpg', 'emerald_34.jpg', 'emerald_15.jpg', 'emerald_22.jpg', 'emerald_30.jpg', 'emerald_9.jpg', 'emerald_32.jpg', 'emerald_11.jpg', 'emerald_31.jpg', 'emerald_24.jpg', 'emerald_35.jpg', 'emerald_10.jpg', 'emerald_12.jpg', 'emerald_20.jpg', 'emerald_33.jpg', 'emerald_37.jpg', 'emerald_28.jpg', 'emerald_21.jpg', 'emerald_29.jpg', 'emerald_13.jpg', 'emerald_7.jpg', 'emerald_26.jpg', 'emerald_17.jpg', 'emerald_14.jpg', 'emerald_1.jpg', 'emerald_40.jpg', 'emerald_36.jpg', 'emerald_16.jpg', 'emerald_39.jpg'] 1
# data/dataset/Onyx Black [] ['onyx black_16.jpg', 'onyx black_10.jpg', 'onyx black_4.jpg', 'onyx black_0.jpg', 'onyx black_30.jpg', 'onyx black_14.jpg', 'onyx black_7.jpg', 'onyx black_31.jpg', 'onyx black_17.jpg', 'onyx black_13.jpg', 'onyx black_12.jpg', 'onyx black_11.jpg', 'onyx black_23.jpg', 'onyx black_29.jpg', 'onyx black_28.jpg', 'onyx black_18.jpg', 'onyx black_22.jpg', 'onyx black_21.jpg', 'onyx black_19.jpg', 'onyx black_27.jpg', 'onyx black_20.jpg', 'onyx black_2.jpg', 'onyx black_5.jpg', 'onyx black_26.jpg', 'onyx black_6.jpg', 'onyx black_15.jpg', 'onyx black_24.jpg', 'onyx black_1.jpg'] 1
# data/dataset/Labradorite [] ['labradorite_35.jpg', 'labradorite_21.jpg', 'labradorite_16.jpg', 'labradorite_11.jpg', 'labradorite_28.jpg', 'labradorite_0.jpg', 'labradorite_32.jpg', 'labradorite_2.jpg', 'labradorite_9.jpg', 'labradorite_14.jpg', 'labradorite_19.jpg', 'labradorite_12.jpg', 'labradorite_31.jpg', 'labradorite_7.jpg', 'labradorite_1.jpg', 'labradorite_20.jpg', 'labradorite_13.jpg', 'labradorite_34.jpg', 'labradorite_5.jpg', 'labradorite_36.jpg', 'labradorite_10.jpg', 'labradorite_6.jpg', 'labradorite_22.jpg', 'labradorite_27.jpg', 'labradorite_26.jpg', 'labradorite_40.jpg', 'labradorite_38.jpg', 'labradorite_30.jpg', 'labradorite_23.jpg', 'labradorite_37.jpg', 'labradorite_24.jpg', 'labradorite_17.jpg', 'labradorite_15.jpg', 'labradorite_8.jpg', 'labradorite_43.jpg', 'labradorite_33.jpg', 'labradorite_39.jpg', 'labradorite_29.jpg', 'labradorite_18.jpg', 'labradorite_25.jpg'] 1
# data/dataset/Benitoite [] ['benitoite_24.jpg', 'benitoite_23.jpg', 'benitoite_30.jpg', 'benitoite_27.jpg', 'benitoite_16.jpg', 'benitoite_22.jpg', 'benitoite_29.jpg', 'benitoite_34.jpg', 'benitoite_20.jpg', 'benitoite_0.jpg', 'benitoite_8.jpg', 'benitoite_6.jpg', 'benitoite_19.jpg', 'benitoite_13.jpg', 'benitoite_25.jpg', 'benitoite_26.jpg', 'benitoite_14.jpg', 'benitoite_32.jpg', 'benitoite_33.jpg', 'benitoite_2.jpg', 'benitoite_17.jpg', 'benitoite_4.jpg', 'benitoite_5.jpg', 'benitoite_10.jpg', 'benitoite_12.jpg', 'benitoite_7.jpg', 'benitoite_31.jpg', 'benitoite_11.jpg', 'benitoite_21.jpg', 'benitoite_15.jpg', 'benitoite_1.jpg'] 1
# data/dataset/Tanzanite [] ['tanzanite_29.jpg', 'tanzanite_30.jpg', 'tanzanite_11.jpg', 'tanzanite_0.jpg', 'tanzanite_8.jpg', 'tanzanite_23.jpg', 'tanzanite_32.jpg', 'tanzanite_2.jpg', 'tanzanite_31.jpg', 'tanzanite_27.jpg', 'tanzanite_18.jpg', 'tanzanite_22.jpg', 'tanzanite_5.jpg', 'tanzanite_34.jpg', 'tanzanite_37.jpg', 'tanzanite_19.jpg', 'tanzanite_15.jpg', 'tanzanite_33.jpg', 'tanzanite_36.jpg', 'tanzanite_1.jpg', 'tanzanite_17.jpg', 'tanzanite_7.jpg', 'tanzanite_25.jpg', 'tanzanite_24.jpg', 'tanzanite_39.jpg', 'tanzanite_38.jpg', 'tanzanite_35.jpg', 'tanzanite_16.jpg', 'tanzanite_12.jpg', 'tanzanite_21.jpg', 'tanzanite_10.jpg', 'tanzanite_14.jpg', 'tanzanite_13.jpg', 'tanzanite_28.jpg', 'tanzanite_26.jpg', 'tanzanite_20.jpg'] 1
# data/dataset/Rhodochrosite [] ['rhodochrosite_23.jpg', 'rhodochrosite_29.jpg', 'rhodochrosite_11.jpg', 'rhodochrosite_16.jpg', 'rhodochrosite_5.jpg', 'rhodochrosite_27.jpg', 'rhodochrosite_15.jpg', 'rhodochrosite_26.jpg', 'rhodochrosite_1.jpg', 'rhodochrosite_20.jpg', 'rhodochrosite_31.jpg', 'rhodochrosite_17.jpg', 'rhodochrosite_14.jpg', 'rhodochrosite_4.jpg', 'rhodochrosite_9.jpg', 'rhodochrosite_24.jpg', 'rhodochrosite_19.jpg', 'rhodochrosite_28.jpg', 'rhodochrosite_13.jpg', 'rhodochrosite_21.jpg', 'rhodochrosite_12.jpg', 'rhodochrosite_10.jpg', 'rhodochrosite_25.jpg', 'rhodochrosite_6.jpg', 'rhodochrosite_8.jpg', 'rhodochrosite_22.jpg', 'rhodochrosite_7.jpg', 'rhodochrosite_0.jpg', 'rhodochrosite_2.jpg'] 1
# data/dataset/Malachite [] ['malachite_23.jpg', 'malachite_6.jpg', 'malachite_30.jpg', 'malachite_19.jpg', 'malachite_31.jpg', 'malachite_1.jpg', 'malachite_18.jpg', 'malachite_21.jpg', 'malachite_11.jpg', 'malachite_7.jpg', 'malachite_2.jpg', 'malachite_27.jpg', 'malachite_13.jpg', 'malachite_22.jpg', 'malachite_14.jpg', 'malachite_10.jpg', 'malachite_24.jpg', 'malachite_17.jpg', 'malachite_4.jpg', 'malachite_29.jpg', 'malachite_16.jpg', 'malachite_5.jpg', 'malachite_12.jpg', 'malachite_20.jpg', 'malachite_26.jpg', 'malachite_15.jpg', 'malachite_0.jpg', 'malachite_28.jpg'] 1
# data/dataset/Diamond [] ['diamond_13.jpg', 'diamond_23.jpg', 'diamond_29.jpg', 'diamond_15.jpg', 'diamond_21.jpg', 'diamond_11.jpg', 'diamond_25.jpg', 'diamond_14.jpg', 'diamond_10.jpg', 'diamond_2.jpg', 'diamond_33.jpg', 'diamond_30.jpg', 'diamond_19.jpg', 'diamond_4.jpg', 'diamond_24.jpg', 'diamond_0.jpg', 'diamond_22.jpg', 'diamond_7.jpg', 'diamond_20.jpg', 'diamond_26.jpg', 'diamond_6.jpg', 'diamond_12.jpg', 'diamond_34.jpg', 'diamond_27.jpg', 'diamond_8.jpg', 'diamond_31.jpg', 'diamond_32.jpg', 'diamond_17.jpg', 'diamond_1.jpg', 'diamond_5.jpg', 'diamond_16.jpg'] 1
# data/dataset/Beryl Golden [] ['beryl golden_18.jpg', 'beryl golden_28.jpg', 'beryl golden_26.jpg', 'beryl golden_27.jpg', 'beryl golden_5.jpg', 'beryl golden_11.jpg', 'beryl golden_37.jpg', 'beryl golden_23.jpg', 'beryl golden_35.jpg', 'beryl golden_30.jpg', 'beryl golden_24.jpg', 'beryl golden_2.jpg', 'beryl golden_39.jpg', 'beryl golden_12.jpg', 'beryl golden_16.jpg', 'beryl golden_36.jpg', 'beryl golden_22.jpg', 'beryl golden_13.jpg', 'beryl golden_34.jpg', 'beryl golden_29.jpg', 'beryl golden_1.jpg', 'beryl golden_32.jpg', 'beryl golden_0.jpg', 'beryl golden_14.jpg', 'beryl golden_21.jpg', 'beryl golden_33.jpg', 'beryl golden_15.jpg', 'beryl golden_7.jpg', 'beryl golden_38.jpg', 'beryl golden_8.jpg', 'beryl golden_17.jpg', 'beryl golden_10.jpg', 'beryl golden_25.jpg', 'beryl golden_19.jpg', 'beryl golden_31.jpg', 'beryl golden_20.jpg'] 1
# data/dataset/Sapphire Blue [] ['sapphire blue_9.jpg', 'sapphire blue_1.jpg', 'sapphire blue_25.jpg', 'sapphire blue_5.jpg', 'sapphire blue_34.jpg', 'sapphire blue_14.jpg', 'sapphire blue_36.jpg', 'sapphire blue_12.jpg', 'sapphire blue_22.jpg', 'sapphire blue_17.jpg', 'sapphire blue_10.jpg', 'sapphire blue_11.jpg', 'sapphire blue_31.jpg', 'sapphire blue_29.jpg', 'sapphire blue_19.jpg', 'sapphire blue_2.jpg', 'sapphire blue_37.jpg', 'sapphire blue_15.jpg', 'sapphire blue_21.jpg', 'sapphire blue_16.jpg', 'sapphire blue_7.jpg', 'sapphire blue_0.jpg', 'sapphire blue_24.jpg', 'sapphire blue_8.jpg', 'sapphire blue_27.jpg', 'sapphire blue_20.jpg', 'sapphire blue_13.jpg', 'sapphire blue_26.jpg', 'sapphire blue_30.jpg', 'sapphire blue_33.jpg', 'sapphire blue_35.jpg', 'sapphire blue_23.jpg', 'sapphire blue_32.jpg', 'sapphire blue_4.jpg'] 1
# data/dataset/Zircon [] ['zircon_27.jpg', 'zircon_35.jpg', 'zircon_36.jpg', 'zircon_11.jpg', 'zircon_13.jpg', 'zircon_17.jpg', 'zircon_12.jpg', 'zircon_25.jpg', 'zircon_14.jpg', 'zircon_5.jpg', 'zircon_24.jpg', 'zircon_6.jpg', 'zircon_1.jpg', 'zircon_8.jpg', 'zircon_4.jpg', 'zircon_33.jpg', 'zircon_30.jpg', 'zircon_15.jpg', 'zircon_20.jpg', 'zircon_0.jpg', 'zircon_19.jpg', 'zircon_22.jpg', 'zircon_34.jpg', 'zircon_10.jpg', 'zircon_9.jpg', 'zircon_16.jpg', 'zircon_31.jpg', 'zircon_2.jpg', 'zircon_21.jpg', 'zircon_32.jpg', 'zircon_26.jpg', 'zircon_23.jpg', 'zircon_29.jpg'] 1
# data/dataset/Carnelian [] ['carnelian_17.jpg', 'carnelian_32.jpg', 'carnelian_27.jpg', 'carnelian_8.jpg', 'carnelian_20.jpg', 'carnelian_23.jpg', 'carnelian_35.jpg', 'carnelian_30.jpg', 'carnelian_26.jpg', 'carnelian_24.jpg', 'carnelian_4.jpg', 'carnelian_22.jpg', 'carnelian_19.jpg', 'carnelian_0.jpg', 'carnelian_33.jpg', 'carnelian_6.jpg', 'carnelian_12.jpg', 'carnelian_29.jpg', 'carnelian_11.jpg', 'carnelian_9.jpg', 'carnelian_31.jpg', 'carnelian_25.jpg', 'carnelian_1.jpg', 'carnelian_2.jpg', 'carnelian_10.jpg', 'carnelian_5.jpg', 'carnelian_36.jpg', 'carnelian_13.jpg', 'carnelian_15.jpg', 'carnelian_16.jpg', 'carnelian_14.jpg', 'carnelian_34.jpg', 'carnelian_21.jpg'] 1
# data/dataset/Cats Eye [] ['cats eye_26.jpg', 'cats eye_6.jpg', 'cats eye_24.jpg', 'cats eye_33.jpg', 'cats eye_0.jpg', 'cats eye_34.jpg', 'cats eye_11.jpg', 'cats eye_20.jpg', 'cats eye_17.jpg', 'cats eye_32.jpg', 'cats eye_22.jpg', 'cats eye_4.jpg', 'cats eye_16.jpg', 'cats eye_27.jpg', 'cats eye_29.jpg', 'cats eye_19.jpg', 'cats eye_1.jpg', 'cats eye_25.jpg', 'cats eye_13.jpg', 'cats eye_21.jpg', 'cats eye_14.jpg', 'cats eye_2.jpg', 'cats eye_23.jpg', 'cats eye_7.jpg', 'cats eye_15.jpg', 'cats eye_10.jpg', 'cats eye_5.jpg', 'cats eye_31.jpg', 'cats eye_30.jpg', 'cats eye_8.jpg', 'cats eye_12.jpg'] 1
# data/dataset/Kunzite [] ['kunzite_23.jpg', 'kunzite_17.jpg', 'kunzite_26.jpg', 'kunzite_10.jpg', 'kunzite_29.jpg', 'kunzite_6.jpg', 'kunzite_25.jpg', 'kunzite_35.jpg', 'kunzite_30.jpg', 'kunzite_24.jpg', 'kunzite_12.jpg', 'kunzite_4.jpg', 'kunzite_19.jpg', 'kunzite_2.jpg', 'kunzite_9.jpg', 'kunzite_0.jpg', 'kunzite_16.jpg', 'kunzite_32.jpg', 'kunzite_27.jpg', 'kunzite_21.jpg', 'kunzite_33.jpg', 'kunzite_5.jpg', 'kunzite_15.jpg', 'kunzite_11.jpg', 'kunzite_22.jpg', 'kunzite_20.jpg', 'kunzite_13.jpg', 'kunzite_34.jpg', 'kunzite_7.jpg', 'kunzite_31.jpg', 'kunzite_1.jpg', 'kunzite_14.jpg'] 1
# data/dataset/Alexandrite [] ['alexandrite_24.jpg', 'alexandrite_19.jpg', 'alexandrite_21.jpg', 'alexandrite_26.jpg', 'alexandrite_30.jpg', 'alexandrite_10.jpg', 'alexandrite_32.jpg', 'alexandrite_23.jpg', 'alexandrite_20.jpg', 'alexandrite_25.jpg', 'alexandrite_35.jpg', 'alexandrite_8.jpg', 'alexandrite_4.jpg', 'alexandrite_17.jpg', 'alexandrite_29.jpg', 'alexandrite_2.jpg', 'alexandrite_15.jpg', 'alexandrite_36.jpg', 'alexandrite_37.jpg', 'alexandrite_31.jpg', 'alexandrite_27.jpg', 'alexandrite_11.jpg', 'alexandrite_7.jpg', 'alexandrite_33.jpg', 'alexandrite_22.jpg', 'alexandrite_34.jpg', 'alexandrite_13.jpg', 'alexandrite_16.jpg', 'alexandrite_1.jpg', 'alexandrite_0.jpg', 'alexandrite_5.jpg', 'alexandrite_9.jpg', 'alexandrite_14.jpg', 'alexandrite_12.jpg'] 1
# data/dataset/Iolite [] ['iolite_29.jpg', 'iolite_4.jpg', 'iolite_7.jpg', 'iolite_30.jpg', 'iolite_17.jpg', 'iolite_26.jpg', 'iolite_24.jpg', 'iolite_10.jpg', 'iolite_27.jpg', 'iolite_0.jpg', 'iolite_13.jpg', 'iolite_2.jpg', 'iolite_16.jpg', 'iolite_15.jpg', 'iolite_31.jpg', 'iolite_25.jpg', 'iolite_32.jpg', 'iolite_1.jpg', 'iolite_19.jpg', 'iolite_22.jpg', 'iolite_23.jpg', 'iolite_5.jpg', 'iolite_20.jpg', 'iolite_21.jpg', 'iolite_34.jpg', 'iolite_9.jpg', 'iolite_35.jpg', 'iolite_6.jpg', 'iolite_12.jpg', 'iolite_33.jpg', 'iolite_14.jpg', 'iolite_11.jpg'] 1
# data/dataset/Danburite [] ['danburite_27.jpg', 'danburite_17.jpg', 'danburite_13.jpg', 'danburite_11.jpg', 'danburite_1.jpg', 'danburite_2.jpg', 'danburite_26.jpg', 'danburite_21.jpg', 'danburite_30.jpg', 'danburite_22.jpg', 'danburite_19.jpg', 'danburite_34.jpg', 'danburite_24.jpg', 'danburite_25.jpg', 'danburite_16.jpg', 'danburite_23.jpg', 'danburite_6.jpg', 'danburite_14.jpg', 'danburite_33.jpg', 'danburite_7.jpg', 'danburite_29.jpg', 'danburite_20.jpg', 'danburite_4.jpg', 'danburite_15.jpg', 'danburite_0.jpg', 'danburite_5.jpg', 'danburite_9.jpg', 'danburite_12.jpg', 'danburite_35.jpg', 'danburite_32.jpg', 'danburite_31.jpg', 'danburite_10.jpg'] 1
# data/dataset/__MACOSX/Emerald [] ['._emerald_16.jpg', '._emerald_29.jpg', '._emerald_25.jpg', '._emerald_33.jpg', '._emerald_28.jpg', '._emerald_37.jpg', '._emerald_11.jpg', '._emerald_2.jpg', '._emerald_10.jpg', '._emerald_39.jpg', '._emerald_20.jpg', '._emerald_0.jpg', '._emerald_35.jpg', '._emerald_34.jpg', '._emerald_15.jpg', '._emerald_26.jpg', '._emerald_6.jpg', '._emerald_1.jpg', '._emerald_22.jpg', '._emerald_13.jpg', '._emerald_9.jpg', '._emerald_24.jpg', '._emerald_7.jpg', '._emerald_17.jpg', '._emerald_31.jpg', '._emerald_36.jpg', '._emerald_21.jpg', '._emerald_27.jpg', '._emerald_14.jpg', '._emerald_19.jpg', '._emerald_30.jpg', '._emerald_12.jpg', '._emerald_38.jpg', '._emerald_23.jpg', '._emerald_40.jpg', '._emerald_32.jpg'] 1
# data/dataset/__MACOSX/Onyx Black [] ['._onyx black_1.jpg', '._onyx black_12.jpg', '._onyx black_30.jpg', '._onyx black_29.jpg', '._onyx black_21.jpg', '._onyx black_6.jpg', '._onyx black_19.jpg', '._onyx black_26.jpg', '._onyx black_22.jpg', '._onyx black_16.jpg', '._onyx black_28.jpg', '._onyx black_2.jpg', '._onyx black_14.jpg', '._onyx black_23.jpg', '._onyx black_15.jpg', '._onyx black_17.jpg', '._onyx black_4.jpg', '._onyx black_0.jpg', '._onyx black_27.jpg', '._onyx black_24.jpg', '._onyx black_13.jpg', '._onyx black_10.jpg', '._onyx black_20.jpg', '._onyx black_18.jpg', '._onyx black_5.jpg', '._onyx black_7.jpg', '._onyx black_11.jpg', '._onyx black_31.jpg'] 1
# data/dataset/__MACOSX/Labradorite [] ['._labradorite_13.jpg', '._labradorite_26.jpg', '._labradorite_36.jpg', '._labradorite_12.jpg', '._labradorite_21.jpg', '._labradorite_43.jpg', '._labradorite_30.jpg', '._labradorite_14.jpg', '._labradorite_39.jpg', '._labradorite_20.jpg', '._labradorite_9.jpg', '._labradorite_22.jpg', '._labradorite_1.jpg', '._labradorite_2.jpg', '._labradorite_0.jpg', '._labradorite_28.jpg', '._labradorite_6.jpg', '._labradorite_38.jpg', '._labradorite_37.jpg', '._labradorite_10.jpg', '._labradorite_5.jpg', '._labradorite_7.jpg', '._labradorite_33.jpg', '._labradorite_11.jpg', '._labradorite_34.jpg', '._labradorite_23.jpg', '._labradorite_29.jpg', '._labradorite_16.jpg', '._labradorite_8.jpg', '._labradorite_17.jpg', '._labradorite_18.jpg', '._labradorite_15.jpg', '._labradorite_35.jpg', '._labradorite_27.jpg', '._labradorite_40.jpg', '._labradorite_32.jpg', '._labradorite_24.jpg', '._labradorite_25.jpg', '._labradorite_31.jpg', '._labradorite_19.jpg'] 1
# data/dataset/__MACOSX/Benitoite [] ['._benitoite_30.jpg', '._benitoite_33.jpg', '._benitoite_6.jpg', '._benitoite_29.jpg', '._benitoite_19.jpg', '._benitoite_1.jpg', '._benitoite_31.jpg', '._benitoite_13.jpg', '._benitoite_4.jpg', '._benitoite_5.jpg', '._benitoite_10.jpg', '._benitoite_16.jpg', '._benitoite_12.jpg', '._benitoite_15.jpg', '._benitoite_24.jpg', '._benitoite_0.jpg', '._benitoite_32.jpg', '._benitoite_7.jpg', '._benitoite_21.jpg', '._benitoite_14.jpg', '._benitoite_17.jpg', '._benitoite_23.jpg', '._benitoite_22.jpg', '._benitoite_2.jpg', '._benitoite_8.jpg', '._benitoite_11.jpg', '._benitoite_26.jpg', '._benitoite_20.jpg', '._benitoite_27.jpg', '._benitoite_34.jpg', '._benitoite_25.jpg'] 1
# data/dataset/__MACOSX/Tanzanite [] ['._tanzanite_12.jpg', '._tanzanite_0.jpg', '._tanzanite_35.jpg', '._tanzanite_19.jpg', '._tanzanite_32.jpg', '._tanzanite_37.jpg', '._tanzanite_22.jpg', '._tanzanite_26.jpg', '._tanzanite_16.jpg', '._tanzanite_10.jpg', '._tanzanite_23.jpg', '._tanzanite_29.jpg', '._tanzanite_24.jpg', '._tanzanite_33.jpg', '._tanzanite_27.jpg', '._tanzanite_14.jpg', '._tanzanite_25.jpg', '._tanzanite_8.jpg', '._tanzanite_20.jpg', '._tanzanite_13.jpg', '._tanzanite_5.jpg', '._tanzanite_17.jpg', '._tanzanite_39.jpg', '._tanzanite_15.jpg', '._tanzanite_30.jpg', '._tanzanite_2.jpg', '._tanzanite_28.jpg', '._tanzanite_7.jpg', '._tanzanite_21.jpg', '._tanzanite_11.jpg', '._tanzanite_1.jpg', '._tanzanite_38.jpg', '._tanzanite_18.jpg', '._tanzanite_34.jpg', '._tanzanite_31.jpg', '._tanzanite_36.jpg'] 1
# data/dataset/__MACOSX/Rhodochrosite [] ['._rhodochrosite_23.jpg', '._rhodochrosite_14.jpg', '._rhodochrosite_16.jpg', '._rhodochrosite_19.jpg', '._rhodochrosite_21.jpg', '._rhodochrosite_20.jpg', '._rhodochrosite_13.jpg', '._rhodochrosite_17.jpg', '._rhodochrosite_12.jpg', '._rhodochrosite_22.jpg', '._rhodochrosite_27.jpg', '._rhodochrosite_2.jpg', '._rhodochrosite_28.jpg', '._rhodochrosite_6.jpg', '._rhodochrosite_7.jpg', '._rhodochrosite_24.jpg', '._rhodochrosite_25.jpg', '._rhodochrosite_4.jpg', '._rhodochrosite_11.jpg', '._rhodochrosite_1.jpg', '._rhodochrosite_5.jpg', '._rhodochrosite_9.jpg', '._rhodochrosite_26.jpg', '._rhodochrosite_29.jpg', '._rhodochrosite_0.jpg', '._rhodochrosite_10.jpg', '._rhodochrosite_15.jpg', '._rhodochrosite_31.jpg', '._rhodochrosite_8.jpg'] 1
# data/dataset/__MACOSX/Malachite [] ['._malachite_20.jpg', '._malachite_23.jpg', '._malachite_29.jpg', '._malachite_18.jpg', '._malachite_31.jpg', '._malachite_10.jpg', '._malachite_5.jpg', '._malachite_13.jpg', '._malachite_21.jpg', '._malachite_15.jpg', '._malachite_24.jpg', '._malachite_22.jpg', '._malachite_19.jpg', '._malachite_7.jpg', '._malachite_11.jpg', '._malachite_17.jpg', '._malachite_6.jpg', '._malachite_2.jpg', '._malachite_16.jpg', '._malachite_1.jpg', '._malachite_0.jpg', '._malachite_14.jpg', '._malachite_26.jpg', '._malachite_4.jpg', '._malachite_28.jpg', '._malachite_30.jpg', '._malachite_12.jpg', '._malachite_27.jpg'] 1
# data/dataset/__MACOSX/Diamond [] ['._diamond_29.jpg', '._diamond_4.jpg', '._diamond_12.jpg', '._diamond_7.jpg', '._diamond_5.jpg', '._diamond_25.jpg', '._diamond_2.jpg', '._diamond_16.jpg', '._diamond_27.jpg', '._diamond_32.jpg', '._diamond_31.jpg', '._diamond_10.jpg', '._diamond_17.jpg', '._diamond_33.jpg', '._diamond_13.jpg', '._diamond_6.jpg', '._diamond_24.jpg', '._diamond_23.jpg', '._diamond_20.jpg', '._diamond_30.jpg', '._diamond_15.jpg', '._diamond_11.jpg', '._diamond_1.jpg', '._diamond_0.jpg', '._diamond_34.jpg', '._diamond_22.jpg', '._diamond_21.jpg', '._diamond_26.jpg', '._diamond_14.jpg', '._diamond_19.jpg', '._diamond_8.jpg'] 1
# data/dataset/__MACOSX/Beryl Golden [] ['._beryl golden_12.jpg', '._beryl golden_38.jpg', '._beryl golden_39.jpg', '._beryl golden_34.jpg', '._beryl golden_26.jpg', '._beryl golden_5.jpg', '._beryl golden_16.jpg', '._beryl golden_17.jpg', '._beryl golden_25.jpg', '._beryl golden_21.jpg', '._beryl golden_18.jpg', '._beryl golden_19.jpg', '._beryl golden_13.jpg', '._beryl golden_27.jpg', '._beryl golden_32.jpg', '._beryl golden_11.jpg', '._beryl golden_1.jpg', '._beryl golden_20.jpg', '._beryl golden_2.jpg', '._beryl golden_28.jpg', '._beryl golden_30.jpg', '._beryl golden_33.jpg', '._beryl golden_8.jpg', '._beryl golden_35.jpg', '._beryl golden_29.jpg', '._beryl golden_22.jpg', '._beryl golden_23.jpg', '._beryl golden_24.jpg', '._beryl golden_14.jpg', '._beryl golden_7.jpg', '._beryl golden_36.jpg', '._beryl golden_10.jpg', '._beryl golden_37.jpg', '._beryl golden_31.jpg', '._beryl golden_0.jpg', '._beryl golden_15.jpg'] 1
# data/dataset/__MACOSX/Sapphire Blue [] ['._sapphire blue_5.jpg', '._sapphire blue_37.jpg', '._sapphire blue_23.jpg', '._sapphire blue_20.jpg', '._sapphire blue_11.jpg', '._sapphire blue_2.jpg', '._sapphire blue_19.jpg', '._sapphire blue_26.jpg', '._sapphire blue_25.jpg', '._sapphire blue_14.jpg', '._sapphire blue_15.jpg', '._sapphire blue_21.jpg', '._sapphire blue_13.jpg', '._sapphire blue_17.jpg', '._sapphire blue_35.jpg', '._sapphire blue_8.jpg', '._sapphire blue_24.jpg', '._sapphire blue_30.jpg', '._sapphire blue_16.jpg', '._sapphire blue_22.jpg', '._sapphire blue_32.jpg', '._sapphire blue_29.jpg', '._sapphire blue_34.jpg', '._sapphire blue_33.jpg', '._sapphire blue_1.jpg', '._sapphire blue_36.jpg', '._sapphire blue_12.jpg', '._sapphire blue_27.jpg', '._sapphire blue_4.jpg', '._sapphire blue_10.jpg', '._sapphire blue_0.jpg', '._sapphire blue_9.jpg', '._sapphire blue_7.jpg', '._sapphire blue_31.jpg'] 1
# data/dataset/__MACOSX/Zircon [] ['._zircon_36.jpg', '._zircon_30.jpg', '._zircon_22.jpg', '._zircon_12.jpg', '._zircon_31.jpg', '._zircon_0.jpg', '._zircon_32.jpg', '._zircon_13.jpg', '._zircon_23.jpg', '._zircon_19.jpg', '._zircon_6.jpg', '._zircon_1.jpg', '._zircon_8.jpg', '._zircon_20.jpg', '._zircon_25.jpg', '._zircon_33.jpg', '._zircon_29.jpg', '._zircon_26.jpg', '._zircon_27.jpg', '._zircon_35.jpg', '._zircon_2.jpg', '._zircon_4.jpg', '._zircon_10.jpg', '._zircon_24.jpg', '._zircon_15.jpg', '._zircon_9.jpg', '._zircon_16.jpg', '._zircon_21.jpg', '._zircon_5.jpg', '._zircon_34.jpg', '._zircon_14.jpg', '._zircon_11.jpg', '._zircon_17.jpg'] 1
# data/dataset/__MACOSX/Carnelian [] ['._carnelian_25.jpg', '._carnelian_22.jpg', '._carnelian_11.jpg', '._carnelian_12.jpg', '._carnelian_5.jpg', '._carnelian_13.jpg', '._carnelian_16.jpg', '._carnelian_15.jpg', '._carnelian_24.jpg', '._carnelian_14.jpg', '._carnelian_2.jpg', '._carnelian_9.jpg', '._carnelian_31.jpg', '._carnelian_1.jpg', '._carnelian_27.jpg', '._carnelian_29.jpg', '._carnelian_10.jpg', '._carnelian_23.jpg', '._carnelian_26.jpg', '._carnelian_4.jpg', '._carnelian_36.jpg', '._carnelian_17.jpg', '._carnelian_8.jpg', '._carnelian_30.jpg', '._carnelian_21.jpg', '._carnelian_19.jpg', '._carnelian_35.jpg', '._carnelian_32.jpg', '._carnelian_6.jpg', '._carnelian_34.jpg', '._carnelian_33.jpg', '._carnelian_20.jpg', '._carnelian_0.jpg'] 1
# data/dataset/__MACOSX/Cats Eye [] ['._cats eye_19.jpg', '._cats eye_10.jpg', '._cats eye_2.jpg', '._cats eye_8.jpg', '._cats eye_23.jpg', '._cats eye_25.jpg', '._cats eye_12.jpg', '._cats eye_15.jpg', '._cats eye_17.jpg', '._cats eye_24.jpg', '._cats eye_29.jpg', '._cats eye_26.jpg', '._cats eye_21.jpg', '._cats eye_31.jpg', '._cats eye_7.jpg', '._cats eye_30.jpg', '._cats eye_5.jpg', '._cats eye_27.jpg', '._cats eye_0.jpg', '._cats eye_6.jpg', '._cats eye_11.jpg', '._cats eye_16.jpg', '._cats eye_33.jpg', '._cats eye_14.jpg', '._cats eye_32.jpg', '._cats eye_1.jpg', '._cats eye_20.jpg', '._cats eye_22.jpg', '._cats eye_34.jpg', '._cats eye_4.jpg', '._cats eye_13.jpg'] 1
# data/dataset/__MACOSX/Kunzite [] ['._kunzite_15.jpg', '._kunzite_32.jpg', '._kunzite_29.jpg', '._kunzite_33.jpg', '._kunzite_0.jpg', '._kunzite_1.jpg', '._kunzite_24.jpg', '._kunzite_16.jpg', '._kunzite_7.jpg', '._kunzite_2.jpg', '._kunzite_4.jpg', '._kunzite_13.jpg', '._kunzite_17.jpg', '._kunzite_31.jpg', '._kunzite_25.jpg', '._kunzite_27.jpg', '._kunzite_34.jpg', '._kunzite_6.jpg', '._kunzite_23.jpg', '._kunzite_20.jpg', '._kunzite_26.jpg', '._kunzite_11.jpg', '._kunzite_35.jpg', '._kunzite_10.jpg', '._kunzite_14.jpg', '._kunzite_21.jpg', '._kunzite_19.jpg', '._kunzite_5.jpg', '._kunzite_30.jpg', '._kunzite_9.jpg', '._kunzite_22.jpg', '._kunzite_12.jpg'] 1
# data/dataset/__MACOSX/Alexandrite [] ['._alexandrite_21.jpg', '._alexandrite_25.jpg', '._alexandrite_26.jpg', '._alexandrite_17.jpg', '._alexandrite_22.jpg', '._alexandrite_29.jpg', '._alexandrite_10.jpg', '._alexandrite_13.jpg', '._alexandrite_20.jpg', '._alexandrite_4.jpg', '._alexandrite_27.jpg', '._alexandrite_34.jpg', '._alexandrite_31.jpg', '._alexandrite_19.jpg', '._alexandrite_14.jpg', '._alexandrite_5.jpg', '._alexandrite_12.jpg', '._alexandrite_2.jpg', '._alexandrite_15.jpg', '._alexandrite_11.jpg', '._alexandrite_9.jpg', '._alexandrite_37.jpg', '._alexandrite_24.jpg', '._alexandrite_16.jpg', '._alexandrite_30.jpg', '._alexandrite_0.jpg', '._alexandrite_36.jpg', '._alexandrite_35.jpg', '._alexandrite_8.jpg', '._alexandrite_33.jpg', '._alexandrite_32.jpg', '._alexandrite_23.jpg', '._alexandrite_7.jpg', '._alexandrite_1.jpg'] 1
# data/dataset/__MACOSX/Iolite [] ['._iolite_4.jpg', '._iolite_22.jpg', '._iolite_25.jpg', '._iolite_24.jpg', '._iolite_32.jpg', '._iolite_1.jpg', '._iolite_5.jpg', '._iolite_6.jpg', '._iolite_30.jpg', '._iolite_7.jpg', '._iolite_12.jpg', '._iolite_10.jpg', '._iolite_34.jpg', '._iolite_14.jpg', '._iolite_9.jpg', '._iolite_26.jpg', '._iolite_16.jpg', '._iolite_21.jpg', '._iolite_33.jpg', '._iolite_29.jpg', '._iolite_15.jpg', '._iolite_17.jpg', '._iolite_35.jpg', '._iolite_11.jpg', '._iolite_0.jpg', '._iolite_19.jpg', '._iolite_2.jpg', '._iolite_20.jpg', '._iolite_13.jpg', '._iolite_31.jpg', '._iolite_23.jpg', '._iolite_27.jpg'] 1
# data/dataset/__MACOSX/Danburite [] ['._danburite_4.jpg', '._danburite_29.jpg', '._danburite_17.jpg', '._danburite_16.jpg', '._danburite_14.jpg', '._danburite_30.jpg', '._danburite_33.jpg', '._danburite_0.jpg', '._danburite_6.jpg', '._danburite_26.jpg', '._danburite_21.jpg', '._danburite_1.jpg', '._danburite_22.jpg', '._danburite_13.jpg', '._danburite_2.jpg', '._danburite_27.jpg', '._danburite_20.jpg', '._danburite_19.jpg', '._danburite_12.jpg', '._danburite_10.jpg', '._danburite_31.jpg', '._danburite_23.jpg', '._danburite_15.jpg', '._danburite_5.jpg', '._danburite_9.jpg', '._danburite_11.jpg', '._danburite_7.jpg', '._danburite_35.jpg', '._danburite_34.jpg', '._danburite_24.jpg', '._danburite_32.jpg', '._danburite_25.jpg'] 1
# data/dataset/__MACOSX/Quartz Beer [] ['._quartz beer_33.jpg', '._quartz beer_12.jpg', '._quartz beer_8.jpg', '._quartz beer_32.jpg', '._quartz beer_25.jpg', '._quartz beer_19.jpg', '._quartz beer_29.jpg', '._quartz beer_20.jpg', '._quartz beer_27.jpg', '._quartz beer_21.jpg', '._quartz beer_38.jpg', '._quartz beer_31.jpg', '._quartz beer_4.jpg', '._quartz beer_23.jpg', '._quartz beer_36.jpg', '._quartz beer_11.jpg', '._quartz beer_2.jpg', '._quartz beer_14.jpg', '._quartz beer_10.jpg', '._quartz beer_22.jpg', '._quartz beer_35.jpg', '._quartz beer_37.jpg', '._quartz beer_0.jpg', '._quartz beer_26.jpg', '._quartz beer_6.jpg', '._quartz beer_28.jpg', '._quartz beer_1.jpg', '._quartz beer_17.jpg', '._quartz beer_30.jpg', '._quartz beer_24.jpg', '._quartz beer_15.jpg', '._quartz beer_9.jpg', '._quartz beer_16.jpg', '._quartz beer_34.jpg', '._quartz beer_13.jpg'] 1
# data/dataset/__MACOSX/Hessonite [] ['._hessonite_4.jpg', '._hessonite_10.jpg', '._hessonite_11.jpg', '._hessonite_20.jpg', '._hessonite_23.jpg', '._hessonite_7.jpg', '._hessonite_17.jpg', '._hessonite_29.jpg', '._hessonite_24.jpg', '._hessonite_21.jpg', '._hessonite_5.jpg', '._hessonite_14.jpg', '._hessonite_32.jpg', '._hessonite_22.jpg', '._hessonite_30.jpg', '._hessonite_15.jpg', '._hessonite_25.jpg', '._hessonite_13.jpg', '._hessonite_31.jpg', '._hessonite_9.jpg', '._hessonite_1.jpg', '._hessonite_27.jpg', '._hessonite_8.jpg', '._hessonite_12.jpg', '._hessonite_26.jpg', '._hessonite_19.jpg', '._hessonite_6.jpg', '._hessonite_33.jpg', '._hessonite_16.jpg', '._hessonite_0.jpg'] 1
# data/dataset/__MACOSX/Jade [] ['._jade_17.jpg', '._jade_23.jpg', '._jade_29.jpg', '._jade_13.jpg', '._jade_14.jpg', '._jade_27.jpg', '._jade_18.jpg', '._jade_30.jpg', '._jade_2.jpg', '._jade_21.jpg', '._jade_15.jpg', '._jade_11.jpg', '._jade_10.jpg', '._jade_0.jpg', '._jade_5.jpg', '._jade_1.jpg', '._jade_28.jpg', '._jade_31.jpg', '._jade_22.jpg', '._jade_7.jpg', '._jade_26.jpg', '._jade_4.jpg', '._jade_6.jpg', '._jade_24.jpg', '._jade_16.jpg', '._jade_20.jpg', '._jade_12.jpg', '._jade_19.jpg'] 1
# data/dataset/__MACOSX/Pearl [] ['._pearl_27.jpg', '._pearl_8.jpg', '._pearl_1.jpg', '._pearl_20.jpg', '._pearl_10.jpg', '._pearl_16.jpg', '._pearl_36.jpg', '._pearl_31.jpg', '._pearl_13.jpg', '._pearl_35.jpg', '._pearl_0.jpg', '._pearl_22.jpg', '._pearl_30.jpg', '._pearl_19.jpg', '._pearl_26.jpg', '._pearl_33.jpg', '._pearl_2.jpg', '._pearl_23.jpg', '._pearl_12.jpg', '._pearl_14.jpg', '._pearl_21.jpg', '._pearl_4.jpg', '._pearl_25.jpg', '._pearl_24.jpg', '._pearl_9.jpg', '._pearl_34.jpg', '._pearl_15.jpg', '._pearl_32.jpg', '._pearl_11.jpg', '._pearl_6.jpg', '._pearl_17.jpg', '._pearl_29.jpg', '._pearl_5.jpg'] 1
# data/dataset/__MACOSX/Almandine [] ['._almandine_13.jpg', '._almandine_8.jpg', '._almandine_26.jpg', '._almandine_24.jpg', '._almandine_10.jpg', '._almandine_27.jpg', '._almandine_32.jpg', '._almandine_11.jpg', '._almandine_23.jpg', '._almandine_20.jpg', '._almandine_2.jpg', '._almandine_4.jpg', '._almandine_1.jpg', '._almandine_0.jpg', '._almandine_14.jpg', '._almandine_21.jpg', '._almandine_16.jpg', '._almandine_7.jpg', '._almandine_30.jpg', '._almandine_31.jpg', '._almandine_34.jpg', '._almandine_15.jpg', '._almandine_33.jpg', '._almandine_5.jpg', '._almandine_22.jpg', '._almandine_12.jpg', '._almandine_17.jpg', '._almandine_6.jpg', '._almandine_29.jpg', '._almandine_25.jpg', '._almandine_19.jpg'] 1
# data/dataset/__MACOSX/Variscite [] ['._variscite_16.jpg', '._variscite_6.jpg', '._variscite_23.jpg', '._variscite_12.jpg', '._variscite_13.jpg', '._variscite_10.jpg', '._variscite_33.jpg', '._variscite_22.jpg', '._variscite_17.jpg', '._variscite_24.jpg', '._variscite_20.jpg', '._variscite_21.jpg', '._variscite_0.jpg', '._variscite_29.jpg', '._variscite_7.jpg', '._variscite_5.jpg', '._variscite_1.jpg', '._variscite_32.jpg', '._variscite_19.jpg', '._variscite_26.jpg', '._variscite_11.jpg', '._variscite_30.jpg', '._variscite_14.jpg', '._variscite_8.jpg', '._variscite_27.jpg', '._variscite_25.jpg', '._variscite_4.jpg', '._variscite_9.jpg', '._variscite_15.jpg', '._variscite_31.jpg'] 1
# data/dataset/__MACOSX/Garnet Red [] ['._garnet red_30.jpg', '._garnet red_0.jpg', '._garnet red_19.jpg', '._garnet red_5.jpg', '._garnet red_2.jpg', '._garnet red_25.jpg', '._garnet red_12.jpg', '._garnet red_36.jpg', '._garnet red_29.jpg', '._garnet red_20.jpg', '._garnet red_10.jpg', '._garnet red_7.jpg', '._garnet red_27.jpg', '._garnet red_26.jpg', '._garnet red_14.jpg', '._garnet red_33.jpg', '._garnet red_15.jpg', '._garnet red_16.jpg', '._garnet red_39.jpg', '._garnet red_32.jpg', '._garnet red_17.jpg', '._garnet red_22.jpg', '._garnet red_1.jpg', '._garnet red_38.jpg', '._garnet red_28.jpg', '._garnet red_34.jpg', '._garnet red_23.jpg', '._garnet red_13.jpg', '._garnet red_31.jpg', '._garnet red_24.jpg', '._garnet red_37.jpg', '._garnet red_18.jpg', '._garnet red_35.jpg', '._garnet red_11.jpg', '._garnet red_21.jpg', '._garnet red_8.jpg'] 1
# data/dataset/__MACOSX/Fluorite [] ['._fluorite_30.jpg', '._fluorite_4.jpg', '._fluorite_21.jpg', '._fluorite_11.jpg', '._fluorite_9.jpg', '._fluorite_10.jpg', '._fluorite_24.jpg', '._fluorite_32.jpg', '._fluorite_22.jpg', '._fluorite_6.jpg', '._fluorite_16.jpg', '._fluorite_14.jpg', '._fluorite_12.jpg', '._fluorite_19.jpg', '._fluorite_0.jpg', '._fluorite_26.jpg', '._fluorite_25.jpg', '._fluorite_2.jpg', '._fluorite_1.jpg', '._fluorite_13.jpg', '._fluorite_29.jpg', '._fluorite_35.jpg', '._fluorite_27.jpg', '._fluorite_31.jpg', '._fluorite_33.jpg', '._fluorite_5.jpg', '._fluorite_20.jpg', '._fluorite_15.jpg', '._fluorite_34.jpg', '._fluorite_17.jpg', '._fluorite_7.jpg', '._fluorite_23.jpg'] 1
# data/dataset/__MACOSX ['Emerald', 'Onyx Black', 'Labradorite', 'Benitoite', 'Tanzanite', 'Rhodochrosite', 'Malachite', 'Diamond', 'Beryl Golden', 'Sapphire Blue', 'Zircon', 'Carnelian', 'Cats Eye', 'Kunzite', 'Alexandrite', 'Iolite', 'Danburite', 'Quartz Beer', 'Hessonite', 'Jade', 'Pearl', 'Almandine', 'Variscite', 'Garnet Red', 'Fluorite'] [] 1
# data/dataset/Quartz Beer [] ['quartz beer_22.jpg', 'quartz beer_13.jpg', 'quartz beer_24.jpg', 'quartz beer_31.jpg', 'quartz beer_8.jpg', 'quartz beer_36.jpg', 'quartz beer_27.jpg', 'quartz beer_19.jpg', 'quartz beer_4.jpg', 'quartz beer_11.jpg', 'quartz beer_38.jpg', 'quartz beer_29.jpg', 'quartz beer_1.jpg', 'quartz beer_25.jpg', 'quartz beer_2.jpg', 'quartz beer_26.jpg', 'quartz beer_17.jpg', 'quartz beer_20.jpg', 'quartz beer_32.jpg', 'quartz beer_9.jpg', 'quartz beer_35.jpg', 'quartz beer_23.jpg', 'quartz beer_14.jpg', 'quartz beer_0.jpg', 'quartz beer_16.jpg', 'quartz beer_34.jpg', 'quartz beer_28.jpg', 'quartz beer_37.jpg', 'quartz beer_21.jpg', 'quartz beer_12.jpg', 'quartz beer_33.jpg', 'quartz beer_6.jpg', 'quartz beer_15.jpg', 'quartz beer_10.jpg', 'quartz beer_30.jpg'] 1
# data/dataset/Hessonite [] ['hessonite_21.jpg', 'hessonite_10.jpg', 'hessonite_27.jpg', 'hessonite_20.jpg', 'hessonite_13.jpg', 'hessonite_8.jpg', 'hessonite_1.jpg', 'hessonite_7.jpg', 'hessonite_12.jpg', 'hessonite_14.jpg', 'hessonite_0.jpg', 'hessonite_24.jpg', 'hessonite_31.jpg', 'hessonite_32.jpg', 'hessonite_19.jpg', 'hessonite_6.jpg', 'hessonite_33.jpg', 'hessonite_30.jpg', 'hessonite_17.jpg', 'hessonite_15.jpg', 'hessonite_11.jpg', 'hessonite_5.jpg', 'hessonite_22.jpg', 'hessonite_26.jpg', 'hessonite_16.jpg', 'hessonite_9.jpg', 'hessonite_25.jpg', 'hessonite_23.jpg', 'hessonite_4.jpg', 'hessonite_29.jpg'] 1
# data/dataset/Jade [] ['jade_27.jpg', 'jade_4.jpg', 'jade_6.jpg', 'jade_31.jpg', 'jade_21.jpg', 'jade_11.jpg', 'jade_30.jpg', 'jade_12.jpg', 'jade_20.jpg', 'jade_18.jpg', 'jade_22.jpg', 'jade_0.jpg', 'jade_13.jpg', 'jade_15.jpg', 'jade_24.jpg', 'jade_23.jpg', 'jade_19.jpg', 'jade_26.jpg', 'jade_1.jpg', 'jade_29.jpg', 'jade_28.jpg', 'jade_10.jpg', 'jade_14.jpg', 'jade_5.jpg', 'jade_17.jpg', 'jade_2.jpg', 'jade_16.jpg', 'jade_7.jpg'] 1
# data/dataset/Pearl [] ['pearl_6.jpg', 'pearl_4.jpg', 'pearl_33.jpg', 'pearl_5.jpg', 'pearl_10.jpg', 'pearl_20.jpg', 'pearl_16.jpg', 'pearl_31.jpg', 'pearl_36.jpg', 'pearl_21.jpg', 'pearl_22.jpg', 'pearl_26.jpg', 'pearl_24.jpg', 'pearl_14.jpg', 'pearl_34.jpg', 'pearl_25.jpg', 'pearl_1.jpg', 'pearl_2.jpg', 'pearl_9.jpg', 'pearl_29.jpg', 'pearl_8.jpg', 'pearl_15.jpg', 'pearl_17.jpg', 'pearl_12.jpg', 'pearl_19.jpg', 'pearl_27.jpg', 'pearl_30.jpg', 'pearl_32.jpg', 'pearl_23.jpg', 'pearl_35.jpg', 'pearl_13.jpg', 'pearl_11.jpg', 'pearl_0.jpg'] 1
# data/dataset/Almandine [] ['almandine_31.jpg', 'almandine_10.jpg', 'almandine_11.jpg', 'almandine_22.jpg', 'almandine_8.jpg', 'almandine_16.jpg', 'almandine_30.jpg', 'almandine_12.jpg', 'almandine_29.jpg', 'almandine_27.jpg', 'almandine_25.jpg', 'almandine_7.jpg', 'almandine_21.jpg', 'almandine_32.jpg', 'almandine_26.jpg', 'almandine_0.jpg', 'almandine_1.jpg', 'almandine_20.jpg', 'almandine_14.jpg', 'almandine_2.jpg', 'almandine_4.jpg', 'almandine_17.jpg', 'almandine_15.jpg', 'almandine_34.jpg', 'almandine_5.jpg', 'almandine_19.jpg', 'almandine_33.jpg', 'almandine_23.jpg', 'almandine_13.jpg', 'almandine_24.jpg', 'almandine_6.jpg'] 1
# data/dataset/Variscite [] ['variscite_25.jpg', 'variscite_8.jpg', 'variscite_7.jpg', 'variscite_4.jpg', 'variscite_15.jpg', 'variscite_17.jpg', 'variscite_22.jpg', 'variscite_26.jpg', 'variscite_27.jpg', 'variscite_13.jpg', 'variscite_29.jpg', 'variscite_32.jpg', 'variscite_5.jpg', 'variscite_24.jpg', 'variscite_21.jpg', 'variscite_20.jpg', 'variscite_10.jpg', 'variscite_9.jpg', 'variscite_12.jpg', 'variscite_16.jpg', 'variscite_33.jpg', 'variscite_6.jpg', 'variscite_14.jpg', 'variscite_23.jpg', 'variscite_0.jpg', 'variscite_30.jpg', 'variscite_31.jpg', 'variscite_19.jpg', 'variscite_11.jpg', 'variscite_1.jpg'] 1
# data/dataset/Garnet Red [] ['garnet red_0.jpg', 'garnet red_23.jpg', 'garnet red_36.jpg', 'garnet red_10.jpg', 'garnet red_18.jpg', 'garnet red_8.jpg', 'garnet red_21.jpg', 'garnet red_22.jpg', 'garnet red_17.jpg', 'garnet red_31.jpg', 'garnet red_15.jpg', 'garnet red_1.jpg', 'garnet red_2.jpg', 'garnet red_27.jpg', 'garnet red_28.jpg', 'garnet red_16.jpg', 'garnet red_11.jpg', 'garnet red_39.jpg', 'garnet red_5.jpg', 'garnet red_32.jpg', 'garnet red_19.jpg', 'garnet red_13.jpg', 'garnet red_26.jpg', 'garnet red_30.jpg', 'garnet red_20.jpg', 'garnet red_24.jpg', 'garnet red_38.jpg', 'garnet red_29.jpg', 'garnet red_25.jpg', 'garnet red_34.jpg', 'garnet red_33.jpg', 'garnet red_7.jpg', 'garnet red_12.jpg', 'garnet red_37.jpg', 'garnet red_14.jpg', 'garnet red_35.jpg'] 1
# data/dataset/Fluorite [] ['fluorite_14.jpg', 'fluorite_30.jpg', 'fluorite_13.jpg', 'fluorite_21.jpg', 'fluorite_26.jpg', 'fluorite_1.jpg', 'fluorite_5.jpg', 'fluorite_31.jpg', 'fluorite_4.jpg', 'fluorite_2.jpg', 'fluorite_24.jpg', 'fluorite_25.jpg', 'fluorite_10.jpg', 'fluorite_17.jpg', 'fluorite_35.jpg', 'fluorite_33.jpg', 'fluorite_23.jpg', 'fluorite_27.jpg', 'fluorite_6.jpg', 'fluorite_12.jpg', 'fluorite_16.jpg', 'fluorite_22.jpg', 'fluorite_11.jpg', 'fluorite_34.jpg', 'fluorite_32.jpg', 'fluorite_19.jpg', 'fluorite_0.jpg', 'fluorite_9.jpg', 'fluorite_29.jpg', 'fluorite_15.jpg', 'fluorite_7.jpg', 'fluorite_20.jpg'] 1
# data/dataset ['Emerald', 'Onyx Black', 'Labradorite', 'Benitoite', 'Tanzanite', 'Rhodochrosite', 'Malachite', 'Diamond', 'Beryl Golden', 'Sapphire Blue', 'Zircon', 'Carnelian', 'Cats Eye', 'Kunzite', 'Alexandrite', 'Iolite', 'Danburite', '__MACOSX', 'Quartz Beer', 'Hessonite', 'Jade', 'Pearl', 'Almandine', 'Variscite', 'Garnet Red', 'Fluorite'] [] 1
# 数据增强： data/dataset/Emerald
# image： data/dataset/Emerald
# Initialised with 36 image(s) found.
# Output directory set to data/dataset/Emerald/output.
# Processing emerald_40.jpg:   1%|▏         | 13/964 [00:00<00:21, 45.19 Samples/s]Processing emerald_6.jpg:  21%|██        | 199/964 [00:05<00:22, 33.77 Samples/s]

# %%
#每次生成数据列表前，首先清空train.txt和eval.txt
with open(train_list_path, 'w') as f: 
    f.seek(0)
    f.truncate() 
with open(eval_list_path, 'w') as f: 
    f.seek(0)
    f.truncate() 
    
#生成数据列表   
get_data_list(target_path,train_list_path,eval_list_path,augment_path)

'''
构造数据提供器
'''
train_reader = paddle.batch(data_reader(train_list_path),
                            batch_size=batch_size,
                            drop_last=True)
eval_reader = paddle.batch(data_reader(eval_list_path),
                            batch_size=batch_size,
                            drop_last=True)
# Out:
# {'input_size': [3, 64, 64], 'class_dim': 25, 'augment_path': '/home/aistudio/augment', 'src_path': 'data/data55032/archive_train.zip', 'target_path': '/home/aistudio/data/dataset', 'train_list_path': './train_data.txt', 'eval_list_path': './val_data.txt', 'label_dict': {'0': 'Garnet Red', '1': 'Fluorite', '2': 'Carnelian', '3': 'Zircon', '4': 'Tanzanite', '5': 'Cats Eye', '6': 'Quartz Beer', '7': 'Hessonite', '8': 'Diamond', '9': 'Sapphire Blue', '10': 'Malachite', '11': 'Pearl', '12': 'Benitoite', '13': 'Alexandrite', '14': 'Onyx Black', '15': 'Beryl Golden', '16': 'Emerald', '17': 'Kunzite', '18': 'Almandine', '19': 'Variscite', '20': 'Rhodochrosite', '21': 'Danburite', '22': 'Jade', '23': 'Labradorite', '24': 'Iolite'}, 'readme_path': '/home/aistudio/data/readme.json', 'num_epochs': 20, 'train_batch_size': 64, 'learning_strategy': {'lr': 0.001}}
# 生成数据列表完成！

# %%
Batch=0
Batchs=[]
all_train_accs=[]
def draw_train_acc(Batchs, train_accs):
    title="training accs"
    plt.title(title, fontsize=24)
    plt.xlabel("batch", fontsize=14)
    plt.ylabel("acc", fontsize=14)
    plt.plot(Batchs, train_accs, color='green', label='training accs')
    plt.legend()
    plt.grid()
    plt.show()

all_train_loss=[]
def draw_train_loss(Batchs, train_loss):
    title="training loss"
    plt.title(title, fontsize=24)
    plt.xlabel("batch", fontsize=14)
    plt.ylabel("loss", fontsize=14)
    plt.plot(Batchs, train_loss, color='red', label='training loss')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# # 2、定义模型
#
# ### ###在以下cell中完成DNN网络的定义###

# %%
#定义网络
class MyDNN(fluid.dygraph.Layer):
    '''
    卷积神经网络
    '''
    def __init__(self):
        super(MyDNN,self).__init__()
        self.hidden1=fluid.dygraph.Linear(3*64*64,1000, act='relu')
        self.hidden2=fluid.dygraph.Linear(1000,500, act='relu')
        self.hidden3=fluid.dygraph.Linear(500,100, act='relu')
        self.out = fluid.dygraph.Linear(input_dim=100, output_dim=25, act='softmax')

    def forward(self,input):
        x = fluid.layers.reshape(input,shape=[-1,3*64*64])
        x = self.hidden1(x)
        x = self.hidden2(x)
        x = self.hidden3(x)
        x = self.out(x)
        return x

# %% [markdown]
# # 3、训练模型

# %%
with fluid.dygraph.guard(place = fluid.CUDAPlace(0)):
    print(train_parameters['class_dim'])
    print(train_parameters['label_dict'])
    model=MyDNN() #模型实例化
    model.train() #训练模式
    opt=fluid.optimizer.SGDOptimizer(learning_rate=train_parameters['learning_strategy']['lr'], parameter_list=model.parameters())#优化器选用SGD随机梯度下降，学习率为0.001.
    epochs_num=train_parameters['num_epochs'] #迭代次数
    
    for pass_num in range(epochs_num):
        for batch_id,data in enumerate(train_reader()):
            images = np.array([x[0] for x in data]).astype('float32').reshape(-1, 3,64,64)
            labels = np.array([x[1] for x in data]).astype('int64')
            labels = labels[:, np.newaxis]

            image=fluid.dygraph.to_variable(images)
            label=fluid.dygraph.to_variable(labels)

            predict=model(image) #数据传入model
            
            loss=fluid.layers.cross_entropy(predict,label)
            avg_loss=fluid.layers.mean(loss)#获取loss值
            
            acc=fluid.layers.accuracy(predict,label)#计算精度
            
            if batch_id!=0 and batch_id%5==0:
                Batch = Batch+5 
                Batchs.append(Batch)
                all_train_loss.append(avg_loss.numpy()[0])
                all_train_accs.append(acc.numpy()[0])
                
                print("train_pass:{},batch_id:{},train_loss:{},train_acc:{}".format(pass_num,batch_id,avg_loss.numpy(),acc.numpy()))
            
            avg_loss.backward()       
            opt.minimize(avg_loss)    #优化器对象的minimize方法对参数进行更新 
            model.clear_gradients()   #model.clear_gradients()来重置梯度
    fluid.save_dygraph(model.state_dict(),'MyDNN')#保存模型

draw_train_acc(Batchs,all_train_accs)
draw_train_loss(Batchs,all_train_loss)
# Out:
# train_pass:19,batch_id:400,train_loss:[0.24890603],train_acc:[0.96875]

# %% [markdown]
# # 4、模型评估

# %%
#模型评估
with fluid.dygraph.guard():
    accs = []
    model_dict, _ = fluid.load_dygraph('MyDNN')
    model = MyDNN()
    model.load_dict(model_dict) #加载模型参数
    model.eval() #训练模式
    for batch_id,data in enumerate(eval_reader()):#测试集
        images = np.array([x[0] for x in data]).astype('float32').reshape(-1, 3,64,64)
        labels = np.array([x[1] for x in data]).astype('int64')
        labels = labels[:, np.newaxis]
        image=fluid.dygraph.to_variable(images)
        label=fluid.dygraph.to_variable(labels)       
        predict=model(image)       
        acc=fluid.layers.accuracy(predict,label)
        accs.append(acc.numpy()[0])
        avg_acc = np.mean(accs)
    print(avg_acc)
# Out:
# 0.96875

# %% [markdown]
# # 5、模型预测

# %%
import os
import zipfile

def unzip_infer_data(src_path,target_path):
    '''
    解压预测数据集
    '''
    if(not os.path.isdir(target_path)):     
        z = zipfile.ZipFile(src_path, 'r')
        z.extractall(path=target_path)
        z.close()


def load_image(img_path):
    '''
    预测图片预处理
    '''
    img = Image.open(img_path) 
    if img.mode != 'RGB': 
        img = img.convert('RGB') 
    img = img.resize((64, 64), Image.BILINEAR)
    img = np.array(img).astype('float32') 
    img = img.transpose((2, 0, 1))  # HWC to CHW 
    img = img/255                # 像素值归一化 
    return img


infer_src_path = '/home/aistudio/data/data55032/archive_test.zip'
infer_dst_path = '/home/aistudio/data/archive_test'
unzip_infer_data(infer_src_path,infer_dst_path)

# %%
label_dic = train_parameters['label_dict']

'''
模型预测
'''
with fluid.dygraph.guard():
    model_dict, _ = fluid.load_dygraph('MyDNN')
    model = MyDNN()
    model.load_dict(model_dict) #加载模型参数
    model.eval() #训练模式
    
    #展示预测图片
    infer_path='data/archive_test/alexandrite_3.jpg'
    img = Image.open(infer_path)
    plt.imshow(img)          #根据数组绘制图像
    plt.show()               #显示图像

    #对预测图片进行预处理
    infer_imgs = []
    infer_imgs.append(load_image(infer_path))
    infer_imgs = np.array(infer_imgs)
   
    for i in range(len(infer_imgs)):
        data = infer_imgs[i]
        dy_x_data = np.array(data).astype('float32')
        dy_x_data=dy_x_data[np.newaxis,:, : ,:]
        img = fluid.dygraph.to_variable(dy_x_data)
        out = model(img)
        lab = np.argmax(out.numpy())  #argmax():返回最大数的索引

        print("第{}个样本,被预测为：{},真实标签为：{}".format(i+1,label_dic[str(lab)],infer_path.split('/')[-1].split("_")[0]))
        
print("结束")
# Out:
# 第1个样本,被预测为：Malachite,真实标签为：alexandrite
# 结束

# %% [markdown]
# # 关于作者：
# * 本人是来自大西北，家境贫寒、不务正业的代码小白,西安电子科技大学毕业生小刘同学，没有什么特别擅长，已脱离开发相关多年,非IT行业,从今年春节开始一直听老师讲课，这是第二次参加训练营了，虽然累，但是收获满满。
# * 老师说我帅，那我就放照片了，让大家说说哪里帅，有多帅
#
#
# <div align = center>
#   <img src="https://ai-studio-static-online.cdn.bcebos.com/7b588061ce7742cc94fd3e5af1bfaeb098eee146f0074d0db9167a44d9767c00"
#             width="367" height="490">
#   </div>
#
# * 感兴趣的方向为：人工智能、信息系统*
# * 最近接触到paddlepaddle，非常感兴趣，希望能够和大家一起交流学习*
# * 欢迎大家fork、一起改进
#
#
# # 关注我关注我 **我的aistdio主页**
#
#
#
#  <div align = center>
#   <img src="https://ai-studio-static-online.cdn.bcebos.com/6aab210e952b415f8fe354e8414822f92bdc837c2706415f8c222c6679c58ee8"
#             width="367" height="490">
#   </div>
#
# * **求求各位英俊帅气的小哥哥，美丽靓丽的小姐姐，多多的关注我**
# * **一定一定要关注啊，我会放好多好多福利的**
# * [https://aistudio.baidu.com/aistudio/personalcenter/thirdview/89263](https://aistudio.baidu.com/aistudio/personalcenter/thirdview/89263)
